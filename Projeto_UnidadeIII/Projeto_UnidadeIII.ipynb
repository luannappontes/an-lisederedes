# %% [markdown]
# # 1.0 Introduction

# %% [markdown]
# In this lesson, we use Twitter data to create and explore directed networks of social interactions. For this lesson, we'll be using a developer workflow where we assume you have access to an app's API key and secret (see the slides).
#
#
# Contents:
#
# 1. Introduction
# 2. Authenticating with Twitter's API
# 2. Twitter API basics
# 3. Using Twitter's search API to get tweets of interest
# 4. Creating social network graphs
# 5. Twitter retweet network
# 6. Twitter mention network
#
# ***Copyright:*** *Parts of the contents of this Colab Notebook, unless otherwise indicated, are Copyright 2020 Filippo Menczer, Santo Fortunato and Clayton A. Davis, [A First Course in Network Science](https://github.com/CambridgeUniversityPress/FirstCourseNetworkScience). All rights reserved.*
#
# ***References***: getting started with the Twitter API v2 for academic research [here](https://github.com/twitterdev/getting-started-with-the-twitter-api-v2-for-academic-research).

# %% [markdown]
# # 2.0 Authenticating with Twitter's API

# %% [markdown]
# Twitter uses OAuth in order to allow third-party apps to access data on your behalf without requiring your Twitter login credentials -- note that none of the code in this notebook asks for your Twitter screen name or password.
#
# The OAuth "dance" can be intimidating when you first use it, but it provides a far more secure way for software to make requests on your behalf than providing your username and password.
#
# We'll make use of the
# [Twython](https://twython.readthedocs.io/en/latest/usage/starting_out.html#authentication)
# package to help us with authentication and querying Twitter's APIs.

# %%
# !pip install Twython
# Out:
# Collecting Twython
#   Downloading twython-3.9.1-py3-none-any.whl (33 kB)
# Requirement already satisfied: requests>=2.1.0 in /usr/local/lib/python3.7/dist-packages (from Twython) (2.23.0)
# Requirement already satisfied: requests-oauthlib>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from Twython) (1.3.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.1.0->Twython) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.1.0->Twython) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.1.0->Twython) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.1.0->Twython) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.4.0->Twython) (3.1.1)
# Installing collected packages: Twython
# Successfully installed Twython-3.9.1

# %%
from twython import Twython, TwythonError

# %% [markdown]
# ## 2.1 Enter app info and get auth URL

# %% [markdown]
# In order to authenticate with Twitter, we'll provide the app details and  ask for a one-time authorization URL to authenticate your user with this app.
#
# Copy and paste the API key and secret from your Twitter app into a file named <font color="red">keys.txt</font>. The first line is the API_KEY and the second line of the file is API_SECRET_KEY. For example, a template for the <font color="red">keys.txt</font>:
#
# ```python
# df6cf09894907b92f3ea749ef
# d19c40cbb184f72055c806f107b5158d023a43eb7d8921a0d0
# ```

# %%
# open the keys file
my_file = open("keys.txt", "r")

# read the raw data
content = my_file.read()

# split all lines by  newline character
API_KEY, API_SECRET_KEY = content.split("\n")

# close the file
my_file.close()

# %% [markdown]
# Executing the cell should then print out a clickable URL. This link is unique and will work **exactly** once. <font color="red"> Visit this URL, log into Twitter, and then copy the verifier pin that is given to you so as to paste it in the next step</font>.

# %%
twitter = Twython(API_KEY, API_SECRET_KEY)

authentication_tokens = twitter.get_authentication_tokens()
print(authentication_tokens['auth_url'])
# Out:
# https://api.twitter.com/oauth/authenticate?oauth_token=u6YWPwAAAAABTXeGAAABe-O46zc

# %% [markdown]
# ## 2.2 Authorize app using verifier PIN

# %% [markdown]
# That verifier PIN goes into the next cell. This will be different every time you run these steps. The `authentication_tokens` include temporary tokens that go with this verifier PIN; by submitting these together, we show Twitter that we are who we say we are.

# %%
# Replace the verifier with the pin number obtained with your web browser in the previous step
VERIFIER = '1234567'

twitter = Twython(API_KEY, API_SECRET_KEY,
                  authentication_tokens['oauth_token'],
                  authentication_tokens['oauth_token_secret'])

authorized_tokens = twitter.get_authorized_tokens(VERIFIER)

# %% [markdown]
# ## 2.3 Use authorized tokens

# %% [markdown]
# Now we have a permanent token pair that we can use to make authenticated calls to the Twitter API. We'll create a new Twython object using these authenticated keys and verify the credentials of the logged-in user.

# %%
twitter = Twython(API_KEY, API_SECRET_KEY,
                  authorized_tokens['oauth_token'],
                  authorized_tokens['oauth_token_secret'])

twitter.verify_credentials()
# Out:
# {'contributors_enabled': False,
#  'created_at': 'Sat Sep 04 10:37:15 +0000 2021',
#  'default_profile': True,
#  'default_profile_image': True,
#  'description': '',
#  'entities': {'description': {'urls': []}},
#  'favourites_count': 0,
#  'follow_request_sent': False,
#  'followers_count': 0,
#  'following': False,
#  'friends_count': 0,
#  'geo_enabled': False,
#  'has_extended_profile': True,
#  'id': 1434103217873432579,
#  'id_str': '1434103217873432579',
#  'is_translation_enabled': False,
#  'is_translator': False,
#  'lang': None,
#  'listed_count': 0,
#  'location': '',
#  'name': 'Luana Pontes',
#  'needs_phone_verification': False,
#  'notifications': False,
#  'profile_background_color': 'F5F8FA',
#  'profile_background_image_url': None,
#  'profile_background_image_url_https': None,
#  'profile_background_tile': False,
#  'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#  'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#  'profile_link_color': '1DA1F2',
#  'profile_sidebar_border_color': 'C0DEED',
#  'profile_sidebar_fill_color': 'DDEEF6',
#  'profile_text_color': '333333',
#  'profile_use_background_image': True,
#  'protected': False,
#  'screen_name': 'LuanaPo71211965',
#  'statuses_count': 0,
#  'suspended': False,
#  'time_zone': None,
#  'translator_type': 'none',
#  'url': None,
#  'utc_offset': None,
#  'verified': False,
#  'withheld_in_countries': []}

# %% [markdown]
# If the previous cell ran without error and printed out a dict corresponding to a
# [Twitter User](https://developer.twitter.com/en/docs/tweets/data-dictionary/overview/user-object),
# then you're good. The authorized token pair is like a username/password and should be protected as such.

# %% [markdown]
# # 3.0 Twitter API basics

# %% [markdown]
# In this lesson, we'll be dealing with two different types of data, Users and Tweets.

# %% [markdown]
# ## 3.1 User objects

# %% [markdown]
# We've already seen one
# [User Object](https://developer.twitter.com/en/docs/tweets/data-dictionary/overview/user-object),
# the one corresponding to the logged-in user, via the call to  `verify_credentials()` above. We can also fetch data for an arbitrary user:

# %%
# fetch data from UFRN's user
user = twitter.show_user(screen_name='ufrnbr')
user
# Out:
# {'contributors_enabled': False,
#  'created_at': 'Wed Oct 07 18:53:18 +0000 2009',
#  'default_profile': False,
#  'default_profile_image': False,
#  'description': 'Perfil oficial da Universidade Federal do Rio Grande do Norte. Fiquem atentos e atentas às nossas novidades!',
#  'entities': {'description': {'urls': []},
#   'url': {'urls': [{'display_url': 'ufrn.br',
#      'expanded_url': 'http://ufrn.br',
#      'indices': [0, 23],
#      'url': 'https://t.co/TQl6GfMToN'}]}},
#  'favourites_count': 2144,
#  'follow_request_sent': False,
#  'followers_count': 15580,
#  'following': False,
#  'friends_count': 86,
#  'geo_enabled': False,
#  'has_extended_profile': True,
#  'id': 80650908,
#  'id_str': '80650908',
#  'is_translation_enabled': False,
#  'is_translator': False,
#  'lang': None,
#  'listed_count': 139,
#  'location': 'Natal/RN',
#  'name': 'UFRN',
#  'notifications': False,
#  'profile_background_color': '54A648',
#  'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_tile': True,
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/80650908/1630939320',
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/1172140887088029697/YnMvivh5_normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1172140887088029697/YnMvivh5_normal.jpg',
#  'profile_link_color': '1B95E0',
#  'profile_location': None,
#  'profile_sidebar_border_color': 'EEEEEE',
#  'profile_sidebar_fill_color': 'F6F6F6',
#  'profile_text_color': '333333',
#  'profile_use_background_image': True,
#  'protected': False,
#  'screen_name': 'ufrnbr',
#  'status': {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Sep 13 20:32:47 +0000 2021',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#      'expanded_url': 'https://twitter.com/i/web/status/1437514617253777408',
#      'indices': [117, 140],
#      'url': 'https://t.co/gcktNF8t0V'}],
#    'user_mentions': []},
#   'favorite_count': 2,
#   'favorited': False,
#   'geo': None,
#   'id': 1437514617253777408,
#   'id_str': '1437514617253777408',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'pt',
#   'place': None,
#   'retweet_count': 1,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'Pesquisadora da UFRN participa amanhã (14) do seminário virtual Comunicação científica: como falar mais alto do que… https://t.co/gcktNF8t0V',
#   'truncated': True},
#  'statuses_count': 34760,
#  'time_zone': None,
#  'translator_type': 'none',
#  'url': 'https://t.co/TQl6GfMToN',
#  'utc_offset': None,
#  'verified': True,
#  'withheld_in_countries': []}

# %% [markdown]
# This dictionary of user data contains several items of note. First, the screen name of the user, while obvious in this case, is very useful later:

# %%
user['screen_name']
# Out:
# 'ufrnbr'

# %% [markdown]
# The user data also contains information such as the number of followers, friends (other users followerd by this user), and tweets (called `'statuses'` in the API):

# %%
print("""
Twitter user @{screen_name}
has {followers_count} followers,
follows {friends_count} users,
and has tweeted {statuses_count} times.
""".format(**user))
# Out:
# Twitter user @ufrnbr
# has 15580 followers,
# follows 86 users,
# and has tweeted 34760 times.

# %% [markdown]
# ### 3.1.1 Playing with followeres with Twython

# %% [markdown]
# It doesn’t need to be said that **Followers** are, and should be, the driving force behind your social success on Twitter. You need to make your **Followers** feel special for Following you. And you need to get as much information about them as possible, so you can analyse your follower demographics for further analysis and targeting. So you can find out exactly how you can make them feel even more special! And feel that following you is worthwhile….
#
# But before you can do any of that, <font color="red"> you first need to get some idea of who your followers are</font>. So let’s start on the basics!
#
# - GET followers/list [documentation](https://developer.twitter.com/en/docs/twitter-api/v1/accounts-and-users/follow-search-get-users/api-reference/get-followers-list).

# %%
# there are some rate limitations in order to use the Twitter API
# you can see the current limits calling get_applicaiton_rate_limit_status()
twitter.get_application_rate_limit_status()['resources']
# Out:
# {'account': {'/account/authenticate_web_view': {'limit': 50,
#    'remaining': 50,
#    'reset': 1631614077},
#   '/account/change_password': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631614077},
#   '/account/login_verification_enrollment': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631614077},
#   '/account/settings': {'limit': 15, 'remaining': 15, 'reset': 1631614077},
#   '/account/update_profile': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631614077},
#   '/account/verify_credentials': {'limit': 75,
#    'remaining': 74,
#    'reset': 1631614065}},
#  'account_activity': {'/account_activity/all/:instance_name/subscriptions': {'limit': 500,
#    'remaining': 500,
#    'reset': 1631614077},
#   '/account_activity/all/:instance_name/webhooks': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631614077},
#   '/account_activity/all/webhooks': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631614077},
#   '/account_activity/direct_messages/:instance_name/subscriptions': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631614077},
#   '/account_activity/direct_messages/:instance_name/webhooks': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631614077},
#   '/account_activity/direct_messages/webhooks': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631614077},
#   '/account_activity/webhooks': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631614077},
#   '/account_activity/webhooks/:id/subscriptions': {'limit': 500,
#    'remaining': 500,
#    'reset': 1631614077},
#   '/account_activity/webhooks/:id/subscriptions/all': {'limit': 500,
#    'remaining': 500,
#    'reset': 1631614077},
#   '/account_activity/webhooks/:id/subscriptions/all/list': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631614077},
#   '/account_activity/webhooks/:id/subscriptions/direct_messages': {'limit': 500,
#    'remaining': 500,
#    'reset': 1631614077},
#   '/account_activity/webhooks/:id/subscriptions/direct_messages/list': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631614077}},
#  'admin_users': {'/admin_users': {'limit': 2000,
#    'remaining': 2000,
#    'reset': 1631614077}},
#  'application': {'/application/rate_limit_status': {'limit': 180,
#    'remaining': 180,
#    'reset': 1631614077}},
#  'auth': {'/auth/csrf_token': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631614077}},
#  'blocks': {'/blocks/ids': {'limit': 15, 'remaining': 15, 'reset': 1631614077},
#   '/blocks/list': {'limit': 15, 'remaining': 15, 'reset': 1631614077}},
#  'business_experience': {'/business_experience/dashboard_features': {'limit': 450,
#    'remaining': 450,
#    'reset': 1631614077},
#   '/business_experience/dashboard_settings/destroy': {'limit': 450,
#    'remaining': 450,
#    'reset': 1631614077},
#   '/business_experience/dashboard_settings/show': {'limit': 450,
#    'remaining': 450,
#    'reset': 1631614077},
#   '/business_experience/dashboard_settings/update': {'limit': 450,
#    'remaining': 450,
#    'reset': 1631614077},
#   '/business_experience/keywords': {'limit': 450,
#    'remaining': 450,
#    'reset': 1631614077}},
#  'collections': {'/collections/entries': {'limit': 1000,
#    'remaining': 1000,
#    'reset': 1631614077},
#   '/collections/list': {'limit': 1000, 'remaining': 1000, 'reset': 1631614077},
#   '/collections/show': {'limit': 1000,
#    'remaining': 1000,
#    'reset': 1631614077}},
#  'compliance': {'/compliance/jobs&GET': {'limit': 150,
#    'remaining': 150,
#    'reset': 1631614077},
#   '/compliance/jobs&POST': {'limit': 150,
#    'remaining': 150,
#    'reset': 1631614077},
#   '/compliance/jobs/:job_id': {'limit': 150,
#    'remaining': 150,
#    'reset': 1631614077}},
#  'contacts': {'/contacts/addressbook': {'limit': 300,
#    'remaining': 300,
#    'reset': 1631614077},
#   '/contacts/delete/status': {'limit': 300,
#    'remaining': 300,
#    'reset': 1631614077},
#   '/contacts/uploaded_by': {'limit': 300,
#    'remaining': 300,
#    'reset': 1631614077},
#   '/contacts/users': {'limit': 300, 'remaining': 300, 'reset': 1631614077},
#   '/contacts/users_and_uploaded_by': {'limit': 300,
#    'remaining': 300,
#    'reset': 1631614077}},
#  'custom_profiles': {'/custom_profiles/list': {'limit': 180,
#    'remaining': 180,
#    'reset': 1631614077},
#   '/custom_profiles/show': {'limit': 180,
#    'remaining': 180,
#    'reset': 1631614077}},
#  'device': {'/device/token': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631614077}},
#  'direct_messages': {'/direct_messages': {'limit': 300,
#    'remaining': 300,
#    'reset': 1631614077},
#   '/direct_messages/broadcasts/list': {'limit': 60,
#    'remaining': 60,
#    'reset': 1631614077},
#   '/direct_messages/broadcasts/show': {'limit': 60,
#    'remaining': 60,
#    'reset': 1631614077},
#   '/direct_messages/broadcasts/statuses/list': {'limit': 60,
#    'remaining': 60,
#    'reset': 1631614077},
#   '/direct_messages/broadcasts/statuses/show': {'limit': 60,
#    'remaining': 60,
#    'reset': 1631614077},
#   '/direct_messages/events/list': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631614077},
#   '/direct_messages/events/show': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631614077},
#   '/direct_messages/mark_read': {'limit': 1000,
#    'remaining': 1000,
#    'reset': 1631614077},
#   '/direct_messages/sent': {'limit': 300,
#    'remaining': 300,
#    'reset': 1631614077},
#   '/direct_messages/sent_and_received': {'limit': 300,
#    'remaining': 300,
#    'reset': 1631614077},
#   '/direct_messages/show': {'limit': 300,
#    'remaining': 300,
#    'reset': 1631614077},
#   '/direct_messages/subscribers/ids': {'limit': 180,
#    'remaining': 180,
#    'reset': 1631614077},
#   '/direct_messages/subscribers/lists/list': {'limit': 180,
#    'remaining': 180,
#    'reset': 1631614077},
#   '/direct_messages/subscribers/lists/members/ids': {'limit': 180,
#    'remaining': 180,
#    'reset': 1631614077},
#   '/direct_messages/subscribers/lists/members/show': {'limit': 1000,
#    'remaining': 1000,
#    'reset': 1631614077},
#   '/direct_messages/subscribers/lists/show': {'limit': 180,
#    'remaining': 180,
#    'reset': 1631614077},
#   '/direct_messages/subscribers/show': {'limit': 180,
#    'remaining': 180,
#    'reset': 1631614077}},
#  'drafts': {'/drafts/statuses/create': {'limit': 450,
#    'remaining': 450,
#    'reset': 1631614077},
#   '/drafts/statuses/destroy': {'limit': 450,
#    'remaining': 450,
#    'reset': 1631614077},
#   '/drafts/statuses/ids': {'limit': 450,
#    'remaining': 450,
#    'reset': 1631614077},
#   '/drafts/statuses/list': {'limit': 450,
#    'remaining': 450,
#    'reset': 1631614077},
#   '/drafts/statuses/show': {'limit': 450,
#    'remaining': 450,
#    'reset': 1631614077},
#   '/drafts/statuses/update': {'limit': 450,
#    'remaining': 450,
#    'reset': 1631614077}},
#  'favorites': {'/favorites/list': {'limit': 75,
#    'remaining': 75,
#    'reset': 1631614077}},
#  'feedback': {'/feedback/events': {'limit': 1000,
#    'remaining': 1000,
#    'reset': 1631614077},
#   '/feedback/show/:id': {'limit': 180, 'remaining': 180, 'reset': 1631614077}},
#  'fleets': {'/fleets/:version/avatar_content': {'limit': 100,
#    'remaining': 100,
#    'reset': 1631614077},
#   '/fleets/:version/create': {'limit': 50,
#    'remaining': 50,
#    'reset': 1631614077},
#   '/fleets/:version/delete': {'limit': 50,
#    'remaining': 50,
#    'reset': 1631614077},
#   '/fleets/:version/feedback/create': {'limit': 500,
#    'remaining': 500,
#    'reset': 1631614077},
#   '/fleets/:version/fleet_threads': {'limit': 1000,
#    'remaining': 1000,
#    'reset': 1631614077},
#   '/fleets/:version/fleetline': {'limit': 100,
#    'remaining': 100,
#    'reset': 1631614077},
#   '/fleets/:version/home_timeline': {'limit': 100,
#    'remaining': 100,
#    'reset': 1631614077},
#   '/fleets/:version/mark_read': {'limit': 1000,
#    'remaining': 1000,
#    'reset': 1631614077},
#   '/fleets/:version/mutes/create': {'limit': 100,
#    'remaining': 100,
#    'reset': 1631614077},
#   '/fleets/:version/mutes/destroy': {'limit': 100,
#    'remaining': 100,
#    'reset': 1631614077},
#   '/fleets/:version/mutes/list': {'limit': 100,
#    'remaining': 100,
#    'reset': 1631614077},
#   '/fleets/:version/track_events': {'limit': 100,
#    'remaining': 100,
#    'reset': 1631614077},
#   '/fleets/:version/update': {'limit': 50,
#    'remaining': 50,
#    'reset': 1631614077},
#   '/fleets/:version/user_fleets': {'limit': 180,
#    'remaining': 180,
#    'reset': 1631614077},
#   '/fleets/:version/viewers': {'limit': 100,
#    'remaining': 100,
#    'reset': 1631614077}},
#  'followers': {'/followers/ids': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631614077},
#   '/followers/list': {'limit': 15, 'remaining': 15, 'reset': 1631614077}},
#  'friends': {'/friends/following/ids': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631614077},
#   '/friends/following/list': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631614077},
#   '/friends/ids': {'limit': 15, 'remaining': 15, 'reset': 1631614077},
#   '/friends/list': {'limit': 15, 'remaining': 15, 'reset': 1631614077}},
#  'friendships': {'/friendships/incoming': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631614077},
#   '/friendships/list': {'limit': 200, 'remaining': 200, 'reset': 1631614077},
#   '/friendships/lookup': {'limit': 15, 'remaining': 15, 'reset': 1631614077},
#   '/friendships/no_retweets/ids': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631614077},
#   '/friendships/outgoing': {'limit': 15, 'remaining': 15, 'reset': 1631614077},
#   '/friendships/show': {'limit': 180, 'remaining': 180, 'reset': 1631614077}},
#  'geo': {'/geo/id/:place_id': {'limit': 75,
#    'remaining': 75,
#    'reset': 1631614077},
#   '/geo/place_page': {'limit': 75, 'remaining': 75, 'reset': 1631614077},
#   '/geo/reverse_geocode': {'limit': 15, 'remaining': 15, 'reset': 1631614077},
#   '/geo/search': {'limit': 15, 'remaining': 15, 'reset': 1631614077},
#   '/geo/similar_places': {'limit': 15, 'remaining': 15, 'reset': 1631614077}},
#  'graphql': {'/graphql': {'limit': 15, 'remaining': 15, 'reset': 1631614077}},
#  'graphql&POST': {'/graphql&POST': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631614077}},
#  'guide': {'/guide': {'limit': 180, 'remaining': 180, 'reset': 1631614077},
#   '/guide/explore_locations_with_autocomplete': {'limit': 200,
#    'remaining': 200,
#    'reset': 1631614077},
#   '/guide/get_explore_locations': {'limit': 100,
#    'remaining': 100,
#    'reset': 1631614077}},
#  'help': {'/help/configuration': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631614077},
#   '/help/languages': {'limit': 15, 'remaining': 15, 'reset': 1631614077},
#   '/help/privacy': {'limit': 15, 'remaining': 15, 'reset': 1631614077},
#   '/help/settings': {'limit': 15, 'remaining': 15, 'reset': 1631614077},
#   '/help/tos': {'limit': 15, 'remaining': 15, 'reset': 1631614077}},
#  'i': {'/i/config': {'limit': 15, 'remaining': 15, 'reset': 1631614077},
#   '/i/tfb/v1/smb/web/:account_id/payment/save': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631614077}},
#  'labs': {'/labs/2/platform_manipulation/reports': {'limit': 5,
#    'remaining': 5,
#    'reset': 1631614077},
#   '/labs/2/reports': {'limit': 5, 'remaining': 5, 'reset': 1631614077},
#   '/labs/:version/tweets/*': {'limit': 900,
#    'remaining': 900,
#    'reset': 1631614077},
#   '/labs/:version/tweets/:id/hidden&PUT': {'limit': 10,
#    'remaining': 10,
#    'reset': 1631614077},
#   '/labs/:version/tweets/metrics/private': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631614077},
#   '/labs/:version/tweets/search': {'limit': 225,
#    'remaining': 225,
#    'reset': 1631614077},
#   '/labs/:version/tweets/stream/compliance': {'limit': 500,
#    'remaining': 500,
#    'reset': 1631614077},
#   '/labs/:version/tweets/stream/filter/': {'limit': 50,
#    'remaining': 50,
#    'reset': 1631614077},
#   '/labs/:version/tweets/stream/filter/:instance_name': {'limit': 50,
#    'remaining': 50,
#    'reset': 1631614077},
#   '/labs/:version/tweets/stream/filter/rules&POST': {'limit': 450,
#    'remaining': 450,
#    'reset': 1631614077},
#   '/labs/:version/tweets/stream/filter/rules/': {'limit': 450,
#    'remaining': 450,
#    'reset': 1631614077},
#   '/labs/:version/tweets/stream/filter/rules/:instance_name': {'limit': 450,
#    'remaining': 450,
#    'reset': 1631614077},
#   '/labs/:version/tweets/stream/sample': {'limit': 50,
#    'remaining': 50,
#    'reset': 1631614077},
#   '/labs/:version/users/*': {'limit': 900,
#    'remaining': 900,
#    'reset': 1631614077},
#   '/labs/:version/users/:id/tweets': {'limit': 225,
#    'remaining': 225,
#    'reset': 1631614077},
#   '/labs/:version/users/by/username/:handle/tweets': {'limit': 225,
#    'remaining': 225,
#    'reset': 1631614077}},
#  'limiter_scalding_report_creation': {'/limiter_scalding_report_creation': {'limit': 4500,
#    'remaining': 4500,
#    'reset': 1631614077}},
#  'lists': {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1631614077},
#   '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1631614077},
#   '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1631614077},
#   '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1631614077},
#   '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1631614077},
#   '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1631614077},
#   '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1631614077},
#   '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1631614077},
#   '/lists/subscribers/show': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631614077},
#   '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1631614077}},
#  'live_pipeline': {'/live_pipeline/events': {'limit': 180,
#    'remaining': 180,
#    'reset': 1631614077}},
#  'live_video_stream': {'/live_video_stream/status/:id': {'limit': 1000,
#    'remaining': 1000,
#    'reset': 1631614077}},
#  'media': {'/media/upload': {'limit': 500,
#    'remaining': 500,
#    'reset': 1631614077}},
#  'moments': {'/moments/create': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631614077},
#   '/moments/permissions': {'limit': 300,
#    'remaining': 300,
#    'reset': 1631614077},
#   '/moments/statuses/update': {'limit': 5,
#    'remaining': 5,
#    'reset': 1631614077}},
#  'mutes': {'/mutes/users/ids': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631614077},
#   '/mutes/users/list': {'limit': 15, 'remaining': 15, 'reset': 1631614077}},
#  'oauth': {'/oauth/invalidate_token': {'limit': 450,
#    'remaining': 450,
#    'reset': 1631614077},
#   '/oauth/revoke': {'limit': 15, 'remaining': 15, 'reset': 1631614077},
#   '/oauth/revoke_html': {'limit': 15, 'remaining': 15, 'reset': 1631614077}},
#  'paseto': {'/paseto/token': {'limit': 25,
#    'remaining': 25,
#    'reset': 1631614077}},
#  'permissions': {'/permissions/user_permissions': {'limit': 3,
#    'remaining': 3,
#    'reset': 1631614077},
#   '/permissions/user_permissions/admin_email_verification': {'limit': 3,
#    'remaining': 3,
#    'reset': 1631614077}},
#  'safety': {'/safety/detection_feedback': {'limit': 450000,
#    'remaining': 450000,
#    'reset': 1631614077}},
#  'sandbox': {'/sandbox/account_activity/webhooks/:id/subscriptions': {'limit': 500,
#    'remaining': 500,
#    'reset': 1631614077}},
#  'saved_searches': {'/saved_searches/destroy/:id': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631614077},
#   '/saved_searches/list': {'limit': 15, 'remaining': 15, 'reset': 1631614077},
#   '/saved_searches/show/:id': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631614077}},
#  'search': {'/search/tweets': {'limit': 180,
#    'remaining': 148,
#    'reset': 1631613874}},
#  'statuses': {'/statuses/friends': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631614077},
#   '/statuses/home_timeline': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631614077},
#   '/statuses/lookup': {'limit': 900, 'remaining': 900, 'reset': 1631614077},
#   '/statuses/mentions_timeline': {'limit': 75,
#    'remaining': 75,
#    'reset': 1631614077},
#   '/statuses/oembed': {'limit': 180, 'remaining': 180, 'reset': 1631614077},
#   '/statuses/retweeters/ids': {'limit': 75,
#    'remaining': 75,
#    'reset': 1631614077},
#   '/statuses/retweets/:id': {'limit': 75,
#    'remaining': 75,
#    'reset': 1631614077},
#   '/statuses/retweets_of_me': {'limit': 75,
#    'remaining': 75,
#    'reset': 1631614077},
#   '/statuses/show/:id': {'limit': 900, 'remaining': 900, 'reset': 1631614077},
#   '/statuses/user_timeline': {'limit': 900,
#    'remaining': 900,
#    'reset': 1631614077}},
#  'strato': {'/strato/column/None/:id/cms/*': {'limit': 150,
#    'remaining': 150,
#    'reset': 1631614077}},
#  'teams': {'/teams/authorize': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631614077}},
#  'traffic': {'/traffic/map': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631614077}},
#  'trends': {'/trends/available': {'limit': 75,
#    'remaining': 75,
#    'reset': 1631614077},
#   '/trends/closest': {'limit': 75, 'remaining': 75, 'reset': 1631614077},
#   '/trends/place': {'limit': 75, 'remaining': 75, 'reset': 1631614077}},
#  'tweet_prompts': {'/tweet_prompts/report_interaction': {'limit': 180,
#    'remaining': 180,
#    'reset': 1631614077},
#   '/tweet_prompts/show': {'limit': 180,
#    'remaining': 180,
#    'reset': 1631614077}},
#  'tweets': {'/tweets/': {'limit': 900, 'remaining': 900, 'reset': 1631614077},
#   '/tweets/:id': {'limit': 900, 'remaining': 900, 'reset': 1631614077},
#   '/tweets/:id&DELETE': {'limit': 50, 'remaining': 50, 'reset': 1631614077},
#   '/tweets/:id/hidden&PUT': {'limit': 50,
#    'remaining': 50,
#    'reset': 1631614077},
#   '/tweets/:id/retweeted_by': {'limit': 75,
#    'remaining': 75,
#    'reset': 1631614077},
#   '/tweets/:tweet_id/liking_users': {'limit': 75,
#    'remaining': 75,
#    'reset': 1631614077},
#   '/tweets/counts/all': {'limit': 900, 'remaining': 900, 'reset': 1631614077},
#   '/tweets/counts/recent': {'limit': 900,
#    'remaining': 900,
#    'reset': 1631614077},
#   '/tweets/sample/stream': {'limit': 50, 'remaining': 50, 'reset': 1631614077},
#   '/tweets/search/:product/:instance/counts': {'limit': 900,
#    'remaining': 900,
#    'reset': 1631614077},
#   '/tweets/search/:product/:label': {'limit': 1800,
#    'remaining': 1800,
#    'reset': 1631614077},
#   '/tweets/search/all': {'limit': 900, 'remaining': 900, 'reset': 1631614077},
#   '/tweets/search/recent': {'limit': 180,
#    'remaining': 180,
#    'reset': 1631614077},
#   '/tweets/search/stream': {'limit': 50, 'remaining': 50, 'reset': 1631614077},
#   '/tweets/search/stream/rules': {'limit': 450,
#    'remaining': 450,
#    'reset': 1631614077},
#   '/tweets/search/stream/rules&DELETE': {'limit': 450,
#    'remaining': 450,
#    'reset': 1631614077},
#   '/tweets/search/stream/rules&POST': {'limit': 450,
#    'remaining': 450,
#    'reset': 1631614077},
#   '/tweets/search/stream/rules/validation&POST': {'limit': 450,
#    'remaining': 450,
#    'reset': 1631614077}},
#  'tweets&POST': {'/tweets&POST': {'limit': 200,
#    'remaining': 200,
#    'reset': 1631614077}},
#  'users': {'/users/': {'limit': 900, 'remaining': 900, 'reset': 1631614077},
#   '/users/:id': {'limit': 900, 'remaining': 897, 'reset': 1631613935},
#   '/users/:id/blocking': {'limit': 15, 'remaining': 15, 'reset': 1631614077},
#   '/users/:id/blocking&POST': {'limit': 50,
#    'remaining': 50,
#    'reset': 1631614077},
#   '/users/:id/followers': {'limit': 15, 'remaining': 15, 'reset': 1631614077},
#   '/users/:id/following': {'limit': 15, 'remaining': 15, 'reset': 1631614077},
#   '/users/:id/liked_tweets': {'limit': 75,
#    'remaining': 75,
#    'reset': 1631614077},
#   '/users/:id/likes&POST': {'limit': 50, 'remaining': 50, 'reset': 1631614077},
#   '/users/:id/likes/:tweet_id&DELETE': {'limit': 50,
#    'remaining': 50,
#    'reset': 1631614077},
#   '/users/:id/mentions': {'limit': 180, 'remaining': 180, 'reset': 1631614077},
#   '/users/:id/muting&POST': {'limit': 50,
#    'remaining': 50,
#    'reset': 1631614077},
#   '/users/:id/retweets&POST': {'limit': 50,
#    'remaining': 50,
#    'reset': 1631614077},
#   '/users/:id/retweets/:source_tweet_id&DELETE': {'limit': 50,
#    'remaining': 50,
#    'reset': 1631614077},
#   '/users/:id/tweets': {'limit': 900, 'remaining': 900, 'reset': 1631614077},
#   '/users/:source_user_id/blocking/:target_user_id&DELETE': {'limit': 50,
#    'remaining': 50,
#    'reset': 1631614077},
#   '/users/:source_user_id/following&POST': {'limit': 50,
#    'remaining': 50,
#    'reset': 1631614077},
#   '/users/:source_user_id/following/:target_user_id&DELETE': {'limit': 50,
#    'remaining': 50,
#    'reset': 1631614077},
#   '/users/:source_user_id/muting/:target_user_id&DELETE': {'limit': 50,
#    'remaining': 50,
#    'reset': 1631614077},
#   '/users/by': {'limit': 900, 'remaining': 900, 'reset': 1631614077},
#   '/users/by/username/:handle/mentions': {'limit': 180,
#    'remaining': 180,
#    'reset': 1631614077},
#   '/users/by/username/:handle/tweets': {'limit': 900,
#    'remaining': 900,
#    'reset': 1631614077},
#   '/users/by/username/:source_username/following&POST': {'limit': 50,
#    'remaining': 50,
#    'reset': 1631614077},
#   '/users/by/username/:source_username/following/:target_user_name&DELETE': {'limit': 50,
#    'remaining': 50,
#    'reset': 1631614077},
#   '/users/by/username/:username': {'limit': 900,
#    'remaining': 900,
#    'reset': 1631614077},
#   '/users/by/username/:username/followers': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631614077},
#   '/users/by/username/:username/following': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631614077},
#   '/users/contributees/pending': {'limit': 200,
#    'remaining': 200,
#    'reset': 1631614077},
#   '/users/contributors/pending': {'limit': 2000,
#    'remaining': 2000,
#    'reset': 1631614077},
#   '/users/derived_info': {'limit': 15, 'remaining': 15, 'reset': 1631614077},
#   '/users/lookup': {'limit': 900, 'remaining': 900, 'reset': 1631614077},
#   '/users/profile_banner': {'limit': 180,
#    'remaining': 180,
#    'reset': 1631614077},
#   '/users/report_spam': {'limit': 15, 'remaining': 15, 'reset': 1631614077},
#   '/users/search': {'limit': 900, 'remaining': 900, 'reset': 1631614077},
#   '/users/show/:id': {'limit': 900, 'remaining': 900, 'reset': 1631614077},
#   '/users/suggestions': {'limit': 15, 'remaining': 15, 'reset': 1631614077},
#   '/users/suggestions/:slug': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631614077},
#   '/users/suggestions/:slug/members': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631614077}},
#  'verify': {'/verify/:version/access': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631614077},
#   '/verify/:version/account-eligibility': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631614077},
#   '/verify/:version/badge-violation': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631614077},
#   '/verify/:version/badge-violation/violations': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631614077},
#   '/verify/:version/document-formats': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631614077},
#   '/verify/:version/id-document&GET': {'limit': 1000,
#    'remaining': 1000,
#    'reset': 1631614077},
#   '/verify/:version/id-document&POST': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631614077},
#   '/verify/:version/intake': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631614077}},
#  'webhooks': {'/webhooks': {'limit': 15, 'remaining': 15, 'reset': 1631614077},
#   '/webhooks/subscriptions/direct_messages': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631614077}}}

# %%
# current limits to followers/list endpoint
twitter.get_application_rate_limit_status()['resources']['followers']
# Out:
# {'/followers/ids': {'limit': 15, 'remaining': 15, 'reset': 1631614082},
#  '/followers/list': {'limit': 15, 'remaining': 15, 'reset': 1631614082}}

# %%
# During the writing of this notebook UFRN twitter user has
# 15507 followers. So, at maximum is possible to retrieve 200 x 15 followers in just a call.
# Thus, considering only 15 calls are allowed during a window of 15 min
# it will be necessary at least 6 calls to collect all UFRN followers
# 6 calls x 15min = 90min!!!!
15507/(200 * 15)

# %%
import datetime
import pandas as pd

# We need to create empty lists for each of those user characteristics
names = []
usernames = []
ids = []
locations = []
follower_count = []

# Getting today's date
datestamp = datetime.datetime.now().strftime("%Y-%m-%d")

# Asking for the username to get their followers
username = 'ufrnbr'

# This is to go through paginated results
next_cursor = -1

# %%
# Let's try 10 calls (limit is 15), 200 x 10 = 2000 followers
for i in range(10):
  # Getting the user's followers (should all be 1 line)
  # Note that are rate limited in API, see the documentation above.
  get_followers = twitter.get_followers_list(screen_name=username,
                                             count=200,
                                             cursor=next_cursor)
  # For each user returned from our get_followers
  for follower in get_followers["users"]:
      names.append(follower["name"])
      usernames.append(follower["screen_name"])
      ids.append(follower["id"])
      locations.append(follower["location"])
      follower_count.append(follower["followers_count"])
  # next cursor
  next_cursor = get_followers["next_cursor"]

# %%
# for the sake of understanding check again
# current limits to followers/list endpoint
twitter.get_application_rate_limit_status()['resources']['followers']
# Out:
# {'/followers/ids': {'limit': 15, 'remaining': 15, 'reset': 1631614096},
#  '/followers/list': {'limit': 15, 'remaining': 5, 'reset': 1631614086}}

# %%
# create a dataframe using ufrn's followers
df = pd.DataFrame.from_dict({"display_name": names,
                             "username": usernames,
                             "user_id": ids,
                             "location": locations,
                             "followers_count": follower_count})

# check the dataframe
df.head()
# Out:
#           display_name  ... followers_count
# 0  ruben lucas machado  ...             493
# 1         Sigaasincero  ...               1
# 2                 dede  ...              65
# 3         Iasmim Silva  ...               0
# 4   Ariel panda ✨🖤🏳️‍🌈  ...             298
#
# [5 rows x 5 columns]

# %%
# save to a csv file
df.to_csv(username+"-"+datestamp+".csv")

# %% [markdown]
# ## 3.2 Tweet Objects

# %% [markdown]
# The second type of data of which we will make use is the
# [Tweet Object](https://developer.twitter.com/en/docs/tweets/data-dictionary/overview/tweet-object).
# A user object actually contains the user's most recent tweet:

# %%
# fetch data from UFRN's user
user = twitter.show_user(screen_name='ufrnbr')

# %%
most_recent_tweet = user['status']
most_recent_tweet
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Mon Sep 13 20:32:47 +0000 2021',
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#     'expanded_url': 'https://twitter.com/i/web/status/1437514617253777408',
#     'indices': [117, 140],
#     'url': 'https://t.co/gcktNF8t0V'}],
#   'user_mentions': []},
#  'favorite_count': 2,
#  'favorited': False,
#  'geo': None,
#  'id': 1437514617253777408,
#  'id_str': '1437514617253777408',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'pt',
#  'place': None,
#  'retweet_count': 1,
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#  'text': 'Pesquisadora da UFRN participa amanhã (14) do seminário virtual Comunicação científica: como falar mais alto do que… https://t.co/gcktNF8t0V',
#  'truncated': True}

# %% [markdown]
# Tweet objects contain several interesting data and metadata, but the most basic are the `'text'` and `'entities'`. The `'text'` is what you expect it to be: the text of the tweet:

# %%
most_recent_tweet['text']
# Out:
# 'Pesquisadora da UFRN participa amanhã (14) do seminário virtual Comunicação científica: como falar mais alto do que… https://t.co/gcktNF8t0V'

# %% [markdown]
# The `'entities'` field contains several tokens of interest already extracted from the tweet such as hashtags, URLs, images, and mentions of other users:

# %%
most_recent_tweet['entities']
# Out:
# {'hashtags': [],
#  'symbols': [],
#  'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#    'expanded_url': 'https://twitter.com/i/web/status/1437514617253777408',
#    'indices': [117, 140],
#    'url': 'https://t.co/gcktNF8t0V'}],
#  'user_mentions': []}

# %% [markdown]
# In particular, we'll make use of the `'user_mentions'` later:

# %%
most_recent_tweet['entities']['user_mentions']
# Out:
# []

# %% [markdown]
# # 4.0 Using Twitter's search API to get tweets of interest

# %% [markdown]
# Twitter's
# [Search API](https://developer.twitter.com/en/docs/tweets/search/api-reference/get-search-tweets.html)
# allows you to fetch recent tweets according to a query of keywords, URLs, hashtags, user mentions, etc.

# %% [markdown]
# ## 4.1 Get tweets matching a hashtag
#
# We'll make use of the ability to search by hashtags:

# %%
search_response = twitter.search(q='#datascience', count=100)

# %%
search_response
# Out:
# {'search_metadata': {'completed_in': 0.128,
#   'count': 100,
#   'max_id': 1437716160213041165,
#   'max_id_str': '1437716160213041165',
#   'next_results': '?max_id=1437715344509095935&q=%23datascience&count=100&include_entities=1',
#   'query': '%23datascience',
#   'refresh_url': '?since_id=1437716160213041165&q=%23datascience&include_entities=1',
#   'since_id': 0,
#   'since_id_str': '0'},
#  'statuses': [{'contributors': None,
#    'coordinates': None,
#    'created_at': 'Tue Sep 14 09:53:38 +0000 2021',
#    'entities': {'hashtags': [{'indices': [19, 35], 'text': 'machinelearning'},
#      {'indices': [36, 48], 'text': 'datascience'},
#      {'indices': [49, 56], 'text': 'python'},
#      {'indices': [57, 80], 'text': 'artificialintelligence'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 1643123766,
#       'id_str': '1643123766',
#       'indices': [3, 17],
#       'name': 'Umair',
#       'screen_name': 'akbarth3great'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1437716160213041165,
#    'id_str': '1437716160213041165',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 12,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Tue Sep 14 07:57:04 +0000 2021',
#     'entities': {'hashtags': [{'indices': [0, 16], 'text': 'machinelearning'},
#       {'indices': [17, 29], 'text': 'datascience'},
#       {'indices': [30, 37], 'text': 'python'},
#       {'indices': [38, 61], 'text': 'artificialintelligence'}],
#      'symbols': [],
#      'urls': [{'display_url': 'dlvr.it/S7X1JJ',
#        'expanded_url': 'http://dlvr.it/S7X1JJ',
#        'indices': [109, 132],
#        'url': 'https://t.co/qN1dfVNYst'}],
#      'user_mentions': []},
#     'favorite_count': 2,
#     'favorited': False,
#     'geo': None,
#     'id': 1437686825812852736,
#     'id_str': '1437686825812852736',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 12,
#     'retweeted': False,
#     'source': '<a href="https://dlvrit.com/" rel="nofollow">dlvr.it</a>',
#     'text': '#machinelearning #datascience #python #artificialintelligence Running Jupyter Notebook on Visual Studio Code https://t.co/qN1dfVNYst',
#     'truncated': False,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Sat Aug 03 16:18:12 +0000 2013',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': 'I work on self-driving cars for a living',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'umair.gg',
#          'expanded_url': 'http://umair.gg',
#          'indices': [0, 23],
#          'url': 'https://t.co/3Qh7PD2UDW'}]}},
#      'favourites_count': 107,
#      'follow_request_sent': False,
#      'followers_count': 12784,
#      'following': False,
#      'friends_count': 89,
#      'geo_enabled': False,
#      'has_extended_profile': False,
#      'id': 1643123766,
#      'id_str': '1643123766',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': None,
#      'listed_count': 36,
#      'location': 'Tesla',
#      'name': 'Umair',
#      'notifications': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1643123766/1609393780',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1340928058019225601/8_jMhNPt_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1340928058019225601/8_jMhNPt_normal.jpg',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'akbarth3great',
#      'statuses_count': 218102,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': 'https://t.co/3Qh7PD2UDW',
#      'utc_offset': None,
#      'verified': False,
#      'withheld_in_countries': []}},
#    'source': '<a href="https://help.twitter.com/en/using-twitter/how-to-tweet#source-labels" rel="nofollow">manzu</a>',
#    'text': 'RT @akbarth3great: #machinelearning #datascience #python #artificialintelligence Running Jupyter Notebook on Visual Studio Code https://t.c…',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon Apr 28 10:50:14 +0000 2014',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Technophile | Pythonista |大好きなコンピュータプログラミング言語は#Pythonです｡ Sometimes a Bot➖Sometimes a Human➖Sometimes Both. Alumnusجامعة جوبا University of Juba. Runs @junub_bot',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'manzugerald.com',
#         'expanded_url': 'https://manzugerald.com',
#         'indices': [0, 23],
#         'url': 'https://t.co/H9hhWWGPL4'}]}},
#     'favourites_count': 198,
#     'follow_request_sent': False,
#     'followers_count': 3944,
#     'following': False,
#     'friends_count': 3884,
#     'geo_enabled': True,
#     'has_extended_profile': True,
#     'id': 2467565462,
#     'id_str': '2467565462',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': None,
#     'listed_count': 10,
#     'location': '🇯🇵東京都調布市',
#     'name': 'Gerald Manzu',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2467565462/1626430499',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1428679422320599041/UJFSXs-K_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1428679422320599041/UJFSXs-K_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'Mansuk_Lo_Rume',
#     'statuses_count': 28134,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': 'https://t.co/H9hhWWGPL4',
#     'utc_offset': None,
#     'verified': False,
#     'withheld_in_countries': []}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Tue Sep 14 09:53:38 +0000 2021',
#    'entities': {'hashtags': [{'indices': [99, 122],
#       'text': 'ArtificialIntelligence'},
#      {'indices': [123, 126], 'text': 'AI'},
#      {'indices': [127, 139], 'text': 'DataScience'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 799200604040163328,
#       'id_str': '799200604040163328',
#       'indices': [3, 10],
#       'name': 'M. Dey',
#       'screen_name': '_M_Dey'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1437716157524553729,
#    'id_str': '1437716157524553729',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 32,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Mon Sep 06 15:05:01 +0000 2021',
#     'entities': {'hashtags': [{'indices': [87, 110],
#        'text': 'ArtificialIntelligence'},
#       {'indices': [111, 114], 'text': 'AI'}],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#        'expanded_url': 'https://twitter.com/i/web/status/1434895417028714502',
#        'indices': [116, 139],
#        'url': 'https://t.co/e1eDpIS23B'}],
#      'user_mentions': []},
#     'favorite_count': 15,
#     'favorited': False,
#     'geo': None,
#     'id': 1434895417028714502,
#     'id_str': '1434895417028714502',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 32,
#     'retweeted': False,
#     'source': '<a href="http://dynamicsignal.com/" rel="nofollow">Dynamic Signal</a>',
#     'text': 'New artificial intelligence tool could speed up diagnosis of cardiovascular diseases | #ArtificialIntelligence #AI… https://t.co/e1eDpIS23B',
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Thu Nov 17 10:40:47 +0000 2016',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': 'In the #mood for #innovation #digital #technology #ai #iot #datascience #blockchain  #newbusinessmodels |',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'business-analytics-info.fr',
#          'expanded_url': 'https://business-analytics-info.fr/',
#          'indices': [0, 23],
#          'url': 'https://t.co/WNnhoqlVh2'}]}},
#      'favourites_count': 295,
#      'follow_request_sent': False,
#      'followers_count': 1327,
#      'following': False,
#      'friends_count': 4517,
#      'geo_enabled': False,
#      'has_extended_profile': False,
#      'id': 799200604040163328,
#      'id_str': '799200604040163328',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': None,
#      'listed_count': 23,
#      'location': 'Paris, France',
#      'name': 'M. Dey',
#      'notifications': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/799200604040163328/1507298995',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/799206549025603584/G1d1duXU_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/799206549025603584/G1d1duXU_normal.jpg',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'protected': False,
#      'screen_name': '_M_Dey',
#      'statuses_count': 4800,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': 'https://t.co/WNnhoqlVh2',
#      'utc_offset': None,
#      'verified': False,
#      'withheld_in_countries': []}},
#    'source': '<a href="https://mobile.twitter.com/MasonLasagne" rel="nofollow">CoffeeSquirrels</a>',
#    'text': 'RT @_M_Dey: New artificial intelligence tool could speed up diagnosis of cardiovascular diseases | #ArtificialIntelligence #AI #DataScience…',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Fri Nov 01 13:03:05 +0000 2019',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Inspired by tech 💻 single-origin coffee ☕ and sometimes squirrels 🐿️',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 248,
#     'follow_request_sent': False,
#     'followers_count': 115,
#     'following': False,
#     'friends_count': 169,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 1190252501070692354,
#     'id_str': '1190252501070692354',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': None,
#     'listed_count': 1,
#     'location': '',
#     'name': 'MasonLasagne',
#     'notifications': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1190252501070692354/1573058619',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1194908904263733248/J-G6XtKH_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1194908904263733248/J-G6XtKH_normal.png',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'MasonLasagne',
#     'statuses_count': 2191,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False,
#     'withheld_in_countries': []}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Tue Sep 14 09:53:36 +0000 2021',
#    'entities': {'hashtags': [{'indices': [99, 122],
#       'text': 'ArtificialIntelligence'},
#      {'indices': [123, 126], 'text': 'AI'},
#      {'indices': [127, 139], 'text': 'DataScience'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 799200604040163328,
#       'id_str': '799200604040163328',
#       'indices': [3, 10],
#       'name': 'M. Dey',
#       'screen_name': '_M_Dey'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1437716150226505734,
#    'id_str': '1437716150226505734',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 32,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Mon Sep 06 15:05:01 +0000 2021',
#     'entities': {'hashtags': [{'indices': [87, 110],
#        'text': 'ArtificialIntelligence'},
#       {'indices': [111, 114], 'text': 'AI'}],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#        'expanded_url': 'https://twitter.com/i/web/status/1434895417028714502',
#        'indices': [116, 139],
#        'url': 'https://t.co/e1eDpIS23B'}],
#      'user_mentions': []},
#     'favorite_count': 15,
#     'favorited': False,
#     'geo': None,
#     'id': 1434895417028714502,
#     'id_str': '1434895417028714502',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 32,
#     'retweeted': False,
#     'source': '<a href="http://dynamicsignal.com/" rel="nofollow">Dynamic Signal</a>',
#     'text': 'New artificial intelligence tool could speed up diagnosis of cardiovascular diseases | #ArtificialIntelligence #AI… https://t.co/e1eDpIS23B',
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Thu Nov 17 10:40:47 +0000 2016',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': 'In the #mood for #innovation #digital #technology #ai #iot #datascience #blockchain  #newbusinessmodels |',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'business-analytics-info.fr',
#          'expanded_url': 'https://business-analytics-info.fr/',
#          'indices': [0, 23],
#          'url': 'https://t.co/WNnhoqlVh2'}]}},
#      'favourites_count': 295,
#      'follow_request_sent': False,
#      'followers_count': 1327,
#      'following': False,
#      'friends_count': 4517,
#      'geo_enabled': False,
#      'has_extended_profile': False,
#      'id': 799200604040163328,
#      'id_str': '799200604040163328',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': None,
#      'listed_count': 23,
#      'location': 'Paris, France',
#      'name': 'M. Dey',
#      'notifications': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/799200604040163328/1507298995',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/799206549025603584/G1d1duXU_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/799206549025603584/G1d1duXU_normal.jpg',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'protected': False,
#      'screen_name': '_M_Dey',
#      'statuses_count': 4800,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': 'https://t.co/WNnhoqlVh2',
#      'utc_offset': None,
#      'verified': False,
#      'withheld_in_countries': []}},
#    'source': '<a href="https://help.twitter.com/en/using-twitter/how-to-tweet#source-labels" rel="nofollow">optimistic_bot</a>',
#    'text': 'RT @_M_Dey: New artificial intelligence tool could speed up diagnosis of cardiovascular diseases | #ArtificialIntelligence #AI #DataScience…',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon Oct 05 03:21:45 +0000 2020',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': "A basic AI driven bot, which retweet tweets that have 'Artificial Intelligence' in their content. \n\n-created by @harshamullapud1 using Py",
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 5,
#     'follow_request_sent': False,
#     'followers_count': 1658,
#     'following': False,
#     'friends_count': 6,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 1312955874940395520,
#     'id_str': '1312955874940395520',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': None,
#     'listed_count': 61,
#     'location': '',
#     'name': 'AI Bot',
#     'notifications': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1312955874940395520/1602437430',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1314973913584001024/JIUouGD3_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1314973913584001024/JIUouGD3_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'Artificialbra1n',
#     'statuses_count': 696421,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False,
#     'withheld_in_countries': []}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Tue Sep 14 09:53:30 +0000 2021',
#    'entities': {'hashtags': [{'indices': [43, 59], 'text': 'programmingjoke'},
#      {'indices': [60, 65], 'text': 'code'},
#      {'indices': [66, 73], 'text': 'coding'},
#      {'indices': [74, 85], 'text': 'javascript'},
#      {'indices': [86, 93], 'text': 'python'},
#      {'indices': [94, 106], 'text': 'datascience'},
#      {'indices': [107, 119], 'text': 'programming'},
#      {'indices': [120, 131], 'text': 'programmer'},
#      {'indices': [132, 137], 'text': 'joke'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 1272948619822264320,
#       'id_str': '1272948619822264320',
#       'indices': [3, 15],
#       'name': 'Garbage collector 🗑️',
#       'screen_name': 'mytrashcode'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1437716126050488320,
#    'id_str': '1437716126050488320',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 60,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Fri Sep 10 10:00:04 +0000 2021',
#     'entities': {'hashtags': [{'indices': [26, 42], 'text': 'programmingjoke'},
#       {'indices': [43, 48], 'text': 'code'},
#       {'indices': [49, 56], 'text': 'coding'},
#       {'indices': [57, 68], 'text': 'javascript'},
#       {'indices': [69, 76], 'text': 'python'},
#       {'indices': [77, 89], 'text': 'datascience'},
#       {'indices': [90, 102], 'text': 'programming'},
#       {'indices': [103, 114], 'text': 'programmer'}],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#        'expanded_url': 'https://twitter.com/i/web/status/1436268227479359498',
#        'indices': [116, 139],
#        'url': 'https://t.co/3xMtAQzlAX'}],
#      'user_mentions': []},
#     'favorite_count': 62,
#     'favorited': False,
#     'geo': None,
#     'id': 1436268227479359498,
#     'id_str': '1436268227479359498',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 60,
#     'retweeted': False,
#     'source': '<a href="https://mytrashcode.com/" rel="nofollow">MyTrashCoce</a>',
#     'text': 'No. 1314 programming meme #programmingjoke #code #coding #javascript #python #datascience #programming #programmer… https://t.co/3xMtAQzlAX',
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Tue Jun 16 17:46:22 +0000 2020',
#      'default_profile': True,
#      'default_profile_image': False,
#      'description': '❤️ Follow this space for funny and trash Programming Memes and jokes !',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'mytrashcode.com',
#          'expanded_url': 'https://mytrashcode.com/',
#          'indices': [0, 23],
#          'url': 'https://t.co/TIyHsukvqN'}]}},
#      'favourites_count': 42,
#      'follow_request_sent': False,
#      'followers_count': 3724,
#      'following': False,
#      'friends_count': 0,
#      'geo_enabled': False,
#      'has_extended_profile': False,
#      'id': 1272948619822264320,
#      'id_str': '1272948619822264320',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': None,
#      'listed_count': 26,
#      'location': 'India',
#      'name': 'Garbage collector 🗑️',
#      'notifications': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1272948619822264320/1592502682',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1322852753706639362/7djDp5aC_normal.png',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1322852753706639362/7djDp5aC_normal.png',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'mytrashcode',
#      'statuses_count': 2194,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': 'https://t.co/TIyHsukvqN',
#      'utc_offset': None,
#      'verified': False,
#      'withheld_in_countries': []}},
#    'source': '<a href="https://help.twitter.com/en/using-twitter/how-to-tweet#source-labels" rel="nofollow">Bills Bot</a>',
#    'text': 'RT @mytrashcode: No. 1314 programming meme #programmingjoke #code #coding #javascript #python #datascience #programming #programmer #joke #…',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Wed Feb 24 08:49:15 +0000 2021',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': "I'm a Bot🤖, retweets #100daysofcode #30daysofcode. Created by @sofibilal193.",
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'sofibilal.me',
#         'expanded_url': 'http://sofibilal.me',
#         'indices': [0, 23],
#         'url': 'https://t.co/RtU8sLmchK'}]}},
#     'favourites_count': 1436,
#     'follow_request_sent': False,
#     'followers_count': 502,
#     'following': False,
#     'friends_count': 36,
#     'geo_enabled': False,
#     'has_extended_profile': True,
#     'id': 1364497572509880322,
#     'id_str': '1364497572509880322',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': None,
#     'listed_count': 21,
#     'location': 'Jammu And Kashmir',
#     'name': 'Bills Bot',
#     'notifications': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1364497572509880322/1624815142',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1409184856685174788/hb_i7LvR_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1409184856685174788/hb_i7LvR_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'Bills_Bot',
#     'statuses_count': 158518,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': 'https://t.co/RtU8sLmchK',
#     'utc_offset': None,
#     'verified': False,
#     'withheld_in_countries': []}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Tue Sep 14 09:53:30 +0000 2021',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 609187397,
#       'id_str': '609187397',
#       'indices': [3, 12],
#       'name': 'Michael Li',
#       'screen_name': 'tianhuil'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1437716124486049798,
#    'id_str': '1437716124486049798',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 22,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Wed Sep 08 12:12:13 +0000 2021',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#        'expanded_url': 'https://twitter.com/i/web/status/1435576706878816263',
#        'indices': [117, 140],
#        'url': 'https://t.co/ma5kLjm2uB'}],
#      'user_mentions': []},
#     'favorite_count': 12,
#     'favorited': False,
#     'geo': None,
#     'id': 1435576706878816263,
#     'id_str': '1435576706878816263',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 22,
#     'retweeted': False,
#     'source': '<a href="https://socialpull.globalunderdog.com/" rel="nofollow">Social-Pull-Staging</a>',
#     'text': 'And, crucially, implementing AI programs to detect malignant tumors would only assist radiologists, and would not r… https://t.co/ma5kLjm2uB',
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Fri Jun 15 15:20:57 +0000 2012',
#      'default_profile': True,
#      'default_profile_image': False,
#      'description': '2XFounder & @Google #DataScientist. @a16z @NASA @Princeton #PhD; write for @TechCrunch @WSJ @HarvardBiz',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'datanote.globalunderdog.com',
#          'expanded_url': 'https://datanote.globalunderdog.com/',
#          'indices': [0, 23],
#          'url': 'https://t.co/sUTfd6zsbO'}]}},
#      'favourites_count': 71,
#      'follow_request_sent': False,
#      'followers_count': 5035,
#      'following': False,
#      'friends_count': 4626,
#      'geo_enabled': False,
#      'has_extended_profile': False,
#      'id': 609187397,
#      'id_str': '609187397',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': None,
#      'listed_count': 1342,
#      'location': 'NYC',
#      'name': 'Michael Li',
#      'notifications': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/609187397/1437595627',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/618184546538749952/5nL3gc4f_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/618184546538749952/5nL3gc4f_normal.jpg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'tianhuil',
#      'statuses_count': 39655,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': 'https://t.co/sUTfd6zsbO',
#      'utc_offset': None,
#      'verified': False,
#      'withheld_in_countries': []}},
#    'source': '<a href="https://help.twitter.com/en/using-twitter/how-to-tweet#source-labels" rel="nofollow">djangoapp_1</a>',
#    'text': 'RT @tianhuil: And, crucially, implementing AI programs to detect malignant tumors would only assist radiologists, and would not replace the…',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue Dec 08 22:10:30 +0000 2020',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': "Hi! I'm a Twitter Bot  to like & retweet #django #python. Follow me to get update about #django #python. If u like Give it a star👇 Dm @ZawadHossain12 for help.",
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'github.com/zawad2221/Twit…',
#         'expanded_url': 'https://github.com/zawad2221/Twitter-Django-Bot',
#         'indices': [0, 23],
#         'url': 'https://t.co/5iGtjQMzYe'}]}},
#     'favourites_count': 11190,
#     'follow_request_sent': False,
#     'followers_count': 1959,
#     'following': False,
#     'friends_count': 1,
#     'geo_enabled': False,
#     'has_extended_profile': True,
#     'id': 1336432915941474305,
#     'id_str': '1336432915941474305',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': None,
#     'listed_count': 40,
#     'location': '',
#     'name': 'Django Bot',
#     'notifications': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1336432915941474305/1607513125',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1336633030018912256/9m938d2h_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1336633030018912256/9m938d2h_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'DjangoBot_',
#     'statuses_count': 551674,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': 'https://t.co/5iGtjQMzYe',
#     'utc_offset': None,
#     'verified': False,
#     'withheld_in_countries': []}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Tue Sep 14 09:53:25 +0000 2021',
#    'entities': {'hashtags': [{'indices': [56, 59], 'text': 'AI'},
#      {'indices': [60, 75], 'text': 'ComputerVision'},
#      {'indices': [76, 92], 'text': 'MachineLearning'},
#      {'indices': [93, 106], 'text': 'DeepLearning'},
#      {'indices': [107, 126], 'text': 'AdversarialAttacks'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 799200604040163328,
#       'id_str': '799200604040163328',
#       'indices': [3, 10],
#       'name': 'M. Dey',
#       'screen_name': '_M_Dey'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1437716104789565440,
#    'id_str': '1437716104789565440',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 9,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Tue Sep 14 09:11:01 +0000 2021',
#     'entities': {'hashtags': [{'indices': [44, 47], 'text': 'AI'},
#       {'indices': [48, 63], 'text': 'ComputerVision'},
#       {'indices': [64, 80], 'text': 'MachineLearning'},
#       {'indices': [81, 94], 'text': 'DeepLearning'},
#       {'indices': [95, 114], 'text': 'AdversarialAttacks'}],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#        'expanded_url': 'https://twitter.com/i/web/status/1437705432928178176',
#        'indices': [116, 139],
#        'url': 'https://t.co/C8XnSO0Ktg'}],
#      'user_mentions': []},
#     'favorite_count': 3,
#     'favorited': False,
#     'geo': None,
#     'id': 1437705432928178176,
#     'id_str': '1437705432928178176',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 9,
#     'retweeted': False,
#     'source': '<a href="http://dynamicsignal.com/" rel="nofollow">Dynamic Signal</a>',
#     'text': "Do deep networks 'see' as well as humans? | #AI #ComputerVision #MachineLearning #DeepLearning #AdversarialAttacks… https://t.co/C8XnSO0Ktg",
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Thu Nov 17 10:40:47 +0000 2016',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': 'In the #mood for #innovation #digital #technology #ai #iot #datascience #blockchain  #newbusinessmodels |',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'business-analytics-info.fr',
#          'expanded_url': 'https://business-analytics-info.fr/',
#          'indices': [0, 23],
#          'url': 'https://t.co/WNnhoqlVh2'}]}},
#      'favourites_count': 295,
#      'follow_request_sent': False,
#      'followers_count': 1327,
#      'following': False,
#      'friends_count': 4517,
#      'geo_enabled': False,
#      'has_extended_profile': False,
#      'id': 799200604040163328,
#      'id_str': '799200604040163328',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': None,
#      'listed_count': 23,
#      'location': 'Paris, France',
#      'name': 'M. Dey',
#      'notifications': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/799200604040163328/1507298995',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/799206549025603584/G1d1duXU_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/799206549025603584/G1d1duXU_normal.jpg',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'protected': False,
#      'screen_name': '_M_Dey',
#      'statuses_count': 4800,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': 'https://t.co/WNnhoqlVh2',
#      'utc_offset': None,
#      'verified': False,
#      'withheld_in_countries': []}},
#    'source': '<a href="https://help.twitter.com/en/using-twitter/how-to-tweet#source-labels" rel="nofollow">SATYAJIT GHOSH</a>',
#    'text': "RT @_M_Dey: Do deep networks 'see' as well as humans? | #AI #ComputerVision #MachineLearning #DeepLearning #AdversarialAttacks #NeuralNetwo…",
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Fri Mar 06 06:52:51 +0000 2015',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': "Dynamic, Dedicated and Determined. Google IT Support Certified. RT's != Endorsement. Stay safe #WearaMask . Sometimes a bot .\nContact: satyajit.ghosh@outlook.in",
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'satyajit.tech',
#         'expanded_url': 'https://satyajit.tech/',
#         'indices': [0, 23],
#         'url': 'https://t.co/nTgOLBPRzO'}]}},
#     'favourites_count': 7637,
#     'follow_request_sent': False,
#     'followers_count': 821,
#     'following': False,
#     'friends_count': 1553,
#     'geo_enabled': True,
#     'has_extended_profile': True,
#     'id': 3064146644,
#     'id_str': '3064146644',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': None,
#     'listed_count': 23,
#     'location': 'Earth',
#     'name': 'SATYAJIT GHOSH',
#     'notifications': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3064146644/1629440021',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1332024623882407939/dBv59xC1_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1332024623882407939/dBv59xC1_normal.jpg',
#     'profile_link_color': '1B95E0',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'SATYAJIT1910',
#     'statuses_count': 106828,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': 'https://t.co/nTgOLBPRzO',
#     'utc_offset': None,
#     'verified': False,
#     'withheld_in_countries': []}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Tue Sep 14 09:53:25 +0000 2021',
#    'entities': {'hashtags': [{'indices': [43, 59], 'text': 'programmingjoke'},
#      {'indices': [60, 65], 'text': 'code'},
#      {'indices': [66, 73], 'text': 'coding'},
#      {'indices': [74, 85], 'text': 'javascript'},
#      {'indices': [86, 93], 'text': 'python'},
#      {'indices': [94, 106], 'text': 'datascience'},
#      {'indices': [107, 119], 'text': 'programming'},
#      {'indices': [120, 131], 'text': 'programmer'},
#      {'indices': [132, 137], 'text': 'joke'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 1272948619822264320,
#       'id_str': '1272948619822264320',
#       'indices': [3, 15],
#       'name': 'Garbage collector 🗑️',
#       'screen_name': 'mytrashcode'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1437716104428888064,
#    'id_str': '1437716104428888064',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 60,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Fri Sep 10 10:00:04 +0000 2021',
#     'entities': {'hashtags': [{'indices': [26, 42], 'text': 'programmingjoke'},
#       {'indices': [43, 48], 'text': 'code'},
#       {'indices': [49, 56], 'text': 'coding'},
#       {'indices': [57, 68], 'text': 'javascript'},
#       {'indices': [69, 76], 'text': 'python'},
#       {'indices': [77, 89], 'text': 'datascience'},
#       {'indices': [90, 102], 'text': 'programming'},
#       {'indices': [103, 114], 'text': 'programmer'}],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#        'expanded_url': 'https://twitter.com/i/web/status/1436268227479359498',
#        'indices': [116, 139],
#        'url': 'https://t.co/3xMtAQzlAX'}],
#      'user_mentions': []},
#     'favorite_count': 62,
#     'favorited': False,
#     'geo': None,
#     'id': 1436268227479359498,
#     'id_str': '1436268227479359498',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 60,
#     'retweeted': False,
#     'source': '<a href="https://mytrashcode.com/" rel="nofollow">MyTrashCoce</a>',
#     'text': 'No. 1314 programming meme #programmingjoke #code #coding #javascript #python #datascience #programming #programmer… https://t.co/3xMtAQzlAX',
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Tue Jun 16 17:46:22 +0000 2020',
#      'default_profile': True,
#      'default_profile_image': False,
#      'description': '❤️ Follow this space for funny and trash Programming Memes and jokes !',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'mytrashcode.com',
#          'expanded_url': 'https://mytrashcode.com/',
#          'indices': [0, 23],
#          'url': 'https://t.co/TIyHsukvqN'}]}},
#      'favourites_count': 42,
#      'follow_request_sent': False,
#      'followers_count': 3724,
#      'following': False,
#      'friends_count': 0,
#      'geo_enabled': False,
#      'has_extended_profile': False,
#      'id': 1272948619822264320,
#      'id_str': '1272948619822264320',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': None,
#      'listed_count': 26,
#      'location': 'India',
#      'name': 'Garbage collector 🗑️',
#      'notifications': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1272948619822264320/1592502682',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1322852753706639362/7djDp5aC_normal.png',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1322852753706639362/7djDp5aC_normal.png',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'mytrashcode',
#      'statuses_count': 2194,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': 'https://t.co/TIyHsukvqN',
#      'utc_offset': None,
#      'verified': False,
#      'withheld_in_countries': []}},
#    'source': '<a href="https://yathinbabu.github.io" rel="nofollow">xael bot</a>',
#    'text': 'RT @mytrashcode: No. 1314 programming meme #programmingjoke #code #coding #javascript #python #datascience #programming #programmer #joke #…',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon May 13 06:56:12 +0000 2019',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': "A bot, I like and retweet on #100DaysOfCode. Block if don't want to be retweeted. Created by @yathinweb",
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'github.com/yathinbabu/100…',
#         'expanded_url': 'https://github.com/yathinbabu/100DaysOfCode-twitter-bot',
#         'indices': [0, 23],
#         'url': 'https://t.co/xcbIJWpgwW'}]}},
#     'favourites_count': 299039,
#     'follow_request_sent': False,
#     'followers_count': 5116,
#     'following': False,
#     'friends_count': 1,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 1127829883013361665,
#     'id_str': '1127829883013361665',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': None,
#     'listed_count': 94,
#     'location': 'Earth',
#     'name': 'xael bot',
#     'notifications': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1127896024737935360/J0nVyVyF_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1127896024737935360/J0nVyVyF_normal.png',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'xaelbot',
#     'statuses_count': 1225220,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': 'https://t.co/xcbIJWpgwW',
#     'utc_offset': None,
#     'verified': False,
#     'withheld_in_countries': []}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Tue Sep 14 09:53:24 +0000 2021',
#    'entities': {'hashtags': [{'indices': [43, 59], 'text': 'programmingjoke'},
#      {'indices': [60, 65], 'text': 'code'},
#      {'indices': [66, 73], 'text': 'coding'},
#      {'indices': [74, 85], 'text': 'javascript'},
#      {'indices': [86, 93], 'text': 'python'},
#      {'indices': [94, 106], 'text': 'datascience'},
#      {'indices': [107, 119], 'text': 'programming'},
#      {'indices': [120, 131], 'text': 'programmer'},
#      {'indices': [132, 137], 'text': 'joke'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 1272948619822264320,
#       'id_str': '1272948619822264320',
#       'indices': [3, 15],
#       'name': 'Garbage collector 🗑️',
# ...
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Tue Sep 14 09:50:24 +0000 2021',
#    'entities': {'hashtags': [{'indices': [19, 26], 'text': 'NodeJS'},
#      {'indices': [46, 54], 'text': 'vacancy'},
#      {'indices': [58, 81], 'text': 'ArtificialIntelligence'},
#      {'indices': [83, 100], 'text': 'DigitalMarketing'},
#      {'indices': [101, 115], 'text': 'cybersecurity'},
#      {'indices': [116, 119], 'text': 'AI'},
#      {'indices': [120, 132], 'text': 'DataScience'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 1364806129717563394,
#       'id_str': '1364806129717563394',
#       'indices': [3, 17],
#       'name': 'W a j d i k a y a l',
#       'screen_name': 'Wajdialkayal1'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1437715344530059270,
#    'id_str': '1437715344530059270',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 102,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Mon Sep 06 14:46:16 +0000 2021',
#     'entities': {'hashtags': [{'indices': [0, 7], 'text': 'NodeJS'},
#       {'indices': [27, 35], 'text': 'vacancy'},
#       {'indices': [39, 62], 'text': 'ArtificialIntelligence'},
#       {'indices': [64, 81], 'text': 'DigitalMarketing'},
#       {'indices': [82, 96], 'text': 'cybersecurity'},
#       {'indices': [97, 100], 'text': 'AI'},
#       {'indices': [101, 113], 'text': 'DataScience'}],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#        'expanded_url': 'https://twitter.com/i/web/status/1434890699619676160',
#        'indices': [115, 138],
#        'url': 'https://t.co/Eq9dltILXU'}],
#      'user_mentions': []},
#     'favorite_count': 34,
#     'favorited': False,
#     'geo': None,
#     'id': 1434890699619676160,
#     'id_str': '1434890699619676160',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': True,
#     'retweet_count': 102,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'text': '#NodeJS. Backend Developer\n#vacancy 🇱🇧\n#ArtificialIntelligence \n#DigitalMarketing\n#cybersecurity\n#AI #DataScience… https://t.co/Eq9dltILXU',
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Thu Feb 25 05:15:21 +0000 2021',
#      'default_profile': True,
#      'default_profile_image': False,
#      'description': '\u200f\u200f\u200f\u200f\u200f\u200f\u200f\u200f\u200f\u200f\u200f\u200f\u200f\u200f\u200f\u200f\u200f\u200f\u200f\u200f\u200f\u200f\u200f\u200f\u200f\u200fأڪثروا الدعاء بتعجيل الفرج فان ذلڪ\nفرجكم\n▶️\nhttps://t.co/aShgfY1XMm\u200e\u200e\u200e\u200e\u200e\u200e\u200e\u200e\u200e\u200e\u200e\u200e\u200e\n▶️\n\u200e\u200e\u200e\u200e🇱🇧\n◀️\nhttps://t.co/ldfMjTjyzU\u200e\u200e\u200e\u200e\u200e\u200e\u200e\u200e\u200e\u200e\u200e\u200e',
#      'entities': {'description': {'urls': [{'display_url': 'wmk-it.net',
#          'expanded_url': 'https://www.wmk-it.net/',
#          'indices': [70, 93],
#          'url': 'https://t.co/aShgfY1XMm'},
#         {'display_url': 'wmk-Tech.net',
#          'expanded_url': 'https://www.wmk-Tech.net/',
#          'indices': [120, 143],
#          'url': 'https://t.co/ldfMjTjyzU'}]},
#       'url': {'urls': [{'display_url': 'wajdialkayal.github.io/site/',
#          'expanded_url': 'https://wajdialkayal.github.io/site/',
#          'indices': [0, 23],
#          'url': 'https://t.co/jHFTEftRDV'}]}},
#      'favourites_count': 12223,
#      'follow_request_sent': False,
#      'followers_count': 1389,
#      'following': False,
#      'friends_count': 1313,
#      'geo_enabled': True,
#      'has_extended_profile': False,
#      'id': 1364806129717563394,
#      'id_str': '1364806129717563394',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': None,
#      'listed_count': 5,
#      'location': 'Lebanon',
#      'name': 'W a j d i k a y a l',
#      'notifications': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1364806129717563394/1614230358',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1383114358855757829/DnlR9xmB_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1383114358855757829/DnlR9xmB_normal.jpg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'Wajdialkayal1',
#      'statuses_count': 12314,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': 'https://t.co/jHFTEftRDV',
#      'utc_offset': None,
#      'verified': False,
#      'withheld_in_countries': []}},
#    'source': '<a href="https://help.twitter.com/en/using-twitter/how-to-tweet#source-labels" rel="nofollow">twitter-nodejs-bot</a>',
#    'text': 'RT @Wajdialkayal1: #NodeJS. Backend Developer\n#vacancy 🇱🇧\n#ArtificialIntelligence \n#DigitalMarketing\n#cybersecurity\n#AI #DataScience #Machi…',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon Jan 22 14:14:28 +0000 2018',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'I am a bot, develop by @jinnatul_md, to retweet #nodejs OR #javascript OR #100daysofCode\n\n⭐https://t.co/GYO2ev1MUU\n\n☕  https://t.co/pfDHuGBNIq',
#     'entities': {'description': {'urls': [{'display_url': 'github.com/jinnatul/twitt…',
#         'expanded_url': 'https://github.com/jinnatul/twitter-bot',
#         'indices': [91, 114],
#         'url': 'https://t.co/GYO2ev1MUU'},
#        {'display_url': 'buymeacoffee.com/jinnatul',
#         'expanded_url': 'http://buymeacoffee.com/jinnatul',
#         'indices': [119, 142],
#         'url': 'https://t.co/pfDHuGBNIq'}]},
#      'url': {'urls': [{'display_url': 'jinnatul.github.io',
#         'expanded_url': 'https://jinnatul.github.io/',
#         'indices': [0, 23],
#         'url': 'https://t.co/kPO1OF5jxM'}]}},
#     'favourites_count': 349,
#     'follow_request_sent': False,
#     'followers_count': 2173,
#     'following': False,
#     'friends_count': 3,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 955443550048608257,
#     'id_str': '955443550048608257',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': None,
#     'listed_count': 46,
#     'location': 'Dhaka, Bangladesh',
#     'name': 'NanoBot',
#     'notifications': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/955443550048608257/1607461296',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1336415584230100992/A8T8B7VJ_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1336415584230100992/A8T8B7VJ_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'morolswediu',
#     'statuses_count': 655916,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': 'https://t.co/kPO1OF5jxM',
#     'utc_offset': None,
#     'verified': False,
#     'withheld_in_countries': []}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Tue Sep 14 09:50:24 +0000 2021',
#    'entities': {'hashtags': [{'indices': [44, 52], 'text': 'vacancy'},
#      {'indices': [53, 61], 'text': 'Lebanon'},
#      {'indices': [62, 67], 'text': 'jobs'},
#      {'indices': [68, 79], 'text': 'javascript'},
#      {'indices': [80, 91], 'text': 'technology'},
#      {'indices': [92, 106], 'text': 'cybersecurity'},
#      {'indices': [107, 130], 'text': 'ArtificialIntelligence'},
#      {'indices': [131, 134], 'text': 'AI'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 1365033981696237571,
#       'id_str': '1365033981696237571',
#       'indices': [3, 16],
#       'name': 'WMK-IT &TECH',
#       'screen_name': 'AlkayalWajdi'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1437715344509095936,
#    'id_str': '1437715344509095936',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 38,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Mon Sep 13 09:07:26 +0000 2021',
#     'entities': {'hashtags': [{'indices': [26, 34], 'text': 'vacancy'},
#       {'indices': [35, 43], 'text': 'Lebanon'},
#       {'indices': [44, 49], 'text': 'jobs'},
#       {'indices': [50, 61], 'text': 'javascript'},
#       {'indices': [62, 73], 'text': 'technology'},
#       {'indices': [74, 88], 'text': 'cybersecurity'},
#       {'indices': [89, 112], 'text': 'ArtificialIntelligence'}],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#        'expanded_url': 'https://twitter.com/i/web/status/1437342145858387971',
#        'indices': [114, 137],
#        'url': 'https://t.co/XOR8Vm2XEw'}],
#      'user_mentions': []},
#     'favorite_count': 18,
#     'favorited': False,
#     'geo': None,
#     'id': 1437342145858387971,
#     'id_str': '1437342145858387971',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 38,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'text': 'MARKETING SUPPORT MANAGER\n#vacancy #Lebanon\n#jobs\n#javascript\n#technology\n#cybersecurity\n#ArtificialIntelligence… https://t.co/XOR8Vm2XEw',
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Thu Feb 25 20:20:47 +0000 2021',
#      'default_profile': True,
#      'default_profile_image': False,
#      'description': '\u200f\u200f\u200fوأعدو لهم ما استطعتم من قوه\n🆚♌▶️\ncustom software development company\n💻\nhttps://t.co/xgDah8q6wx\u200e\u200e\u200e\n♌▶️👇\n\nhttps://t.co/6NGzP7vXQM\u200e\u200e\u200e',
#      'entities': {'description': {'urls': [{'display_url': 'wmk-tech.net',
#          'expanded_url': 'http://wmk-tech.net/',
#          'indices': [74, 97],
#          'url': 'https://t.co/xgDah8q6wx'},
#         {'display_url': 'wajdialkayal.github.io/site/',
#          'expanded_url': 'https://wajdialkayal.github.io/site/',
#          'indices': [107, 130],
#          'url': 'https://t.co/6NGzP7vXQM'}]},
#       'url': {'urls': [{'display_url': 'wmk-it.net',
#          'expanded_url': 'https://www.wmk-it.net/',
#          'indices': [0, 23],
#          'url': 'https://t.co/pCRgB86iF6'}]}},
#      'favourites_count': 14462,
#      'follow_request_sent': False,
#      'followers_count': 2119,
#      'following': False,
#      'friends_count': 2054,
#      'geo_enabled': True,
#      'has_extended_profile': False,
#      'id': 1365033981696237571,
#      'id_str': '1365033981696237571',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': None,
#      'listed_count': 7,
#      'location': '',
#      'name': 'WMK-IT &TECH',
#      'notifications': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1365033981696237571/1614284998',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1369737093690359813/p-D7hM_o_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1369737093690359813/p-D7hM_o_normal.jpg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'AlkayalWajdi',
#      'statuses_count': 13454,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': 'https://t.co/pCRgB86iF6',
#      'utc_offset': None,
#      'verified': False,
#      'withheld_in_countries': []}},
#    'source': '<a href="https://help.twitter.com/en/using-twitter/how-to-tweet#source-labels" rel="nofollow">twitter-nodejs-bot</a>',
#    'text': 'RT @AlkayalWajdi: MARKETING SUPPORT MANAGER\n#vacancy #Lebanon\n#jobs\n#javascript\n#technology\n#cybersecurity\n#ArtificialIntelligence #AI #Dat…',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon Jan 22 14:14:28 +0000 2018',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'I am a bot, develop by @jinnatul_md, to retweet #nodejs OR #javascript OR #100daysofCode\n\n⭐https://t.co/GYO2ev1MUU\n\n☕  https://t.co/pfDHuGBNIq',
#     'entities': {'description': {'urls': [{'display_url': 'github.com/jinnatul/twitt…',
#         'expanded_url': 'https://github.com/jinnatul/twitter-bot',
#         'indices': [91, 114],
#         'url': 'https://t.co/GYO2ev1MUU'},
#        {'display_url': 'buymeacoffee.com/jinnatul',
#         'expanded_url': 'http://buymeacoffee.com/jinnatul',
#         'indices': [119, 142],
#         'url': 'https://t.co/pfDHuGBNIq'}]},
#      'url': {'urls': [{'display_url': 'jinnatul.github.io',
#         'expanded_url': 'https://jinnatul.github.io/',
#         'indices': [0, 23],
#         'url': 'https://t.co/kPO1OF5jxM'}]}},
#     'favourites_count': 349,
#     'follow_request_sent': False,
#     'followers_count': 2173,
#     'following': False,
#     'friends_count': 3,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 955443550048608257,
#     'id_str': '955443550048608257',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': None,
#     'listed_count': 46,
#     'location': 'Dhaka, Bangladesh',
#     'name': 'NanoBot',
#     'notifications': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/955443550048608257/1607461296',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1336415584230100992/A8T8B7VJ_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1336415584230100992/A8T8B7VJ_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'morolswediu',
#     'statuses_count': 655916,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': 'https://t.co/kPO1OF5jxM',
#     'utc_offset': None,
#     'verified': False,
#     'withheld_in_countries': []}}]}

# %%
# current limits to followers/list endpoint
twitter.get_application_rate_limit_status()['resources']["search"]
# Out:
# {'/search/tweets': {'limit': 180, 'remaining': 147, 'reset': 1631613874}}

# %% [markdown]
# While the search API response is a dictionary, the `'statuses'` field contains the list of
# [Tweet Objects](https://developer.twitter.com/en/docs/tweets/data-dictionary/overview/tweet-object)
# we're after.

# %%
search_tweets = search_response['statuses']
tweet = search_tweets[0]
tweet
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Tue Sep 14 09:53:38 +0000 2021',
#  'entities': {'hashtags': [{'indices': [19, 35], 'text': 'machinelearning'},
#    {'indices': [36, 48], 'text': 'datascience'},
#    {'indices': [49, 56], 'text': 'python'},
#    {'indices': [57, 80], 'text': 'artificialintelligence'}],
#   'symbols': [],
#   'urls': [],
#   'user_mentions': [{'id': 1643123766,
#     'id_str': '1643123766',
#     'indices': [3, 17],
#     'name': 'Umair',
#     'screen_name': 'akbarth3great'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 1437716160213041165,
#  'id_str': '1437716160213041165',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#  'place': None,
#  'retweet_count': 12,
#  'retweeted': False,
#  'retweeted_status': {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Sep 14 07:57:04 +0000 2021',
#   'entities': {'hashtags': [{'indices': [0, 16], 'text': 'machinelearning'},
#     {'indices': [17, 29], 'text': 'datascience'},
#     {'indices': [30, 37], 'text': 'python'},
#     {'indices': [38, 61], 'text': 'artificialintelligence'}],
#    'symbols': [],
#    'urls': [{'display_url': 'dlvr.it/S7X1JJ',
#      'expanded_url': 'http://dlvr.it/S7X1JJ',
#      'indices': [109, 132],
#      'url': 'https://t.co/qN1dfVNYst'}],
#    'user_mentions': []},
#   'favorite_count': 2,
#   'favorited': False,
#   'geo': None,
#   'id': 1437686825812852736,
#   'id_str': '1437686825812852736',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 12,
#   'retweeted': False,
#   'source': '<a href="https://dlvrit.com/" rel="nofollow">dlvr.it</a>',
#   'text': '#machinelearning #datascience #python #artificialintelligence Running Jupyter Notebook on Visual Studio Code https://t.co/qN1dfVNYst',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sat Aug 03 16:18:12 +0000 2013',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'I work on self-driving cars for a living',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'umair.gg',
#        'expanded_url': 'http://umair.gg',
#        'indices': [0, 23],
#        'url': 'https://t.co/3Qh7PD2UDW'}]}},
#    'favourites_count': 107,
#    'follow_request_sent': False,
#    'followers_count': 12784,
#    'following': False,
#    'friends_count': 89,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 1643123766,
#    'id_str': '1643123766',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': None,
#    'listed_count': 36,
#    'location': 'Tesla',
#    'name': 'Umair',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1643123766/1609393780',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1340928058019225601/8_jMhNPt_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1340928058019225601/8_jMhNPt_normal.jpg',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'akbarth3great',
#    'statuses_count': 218102,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'https://t.co/3Qh7PD2UDW',
#    'utc_offset': None,
#    'verified': False,
#    'withheld_in_countries': []}},
#  'source': '<a href="https://help.twitter.com/en/using-twitter/how-to-tweet#source-labels" rel="nofollow">manzu</a>',
#  'text': 'RT @akbarth3great: #machinelearning #datascience #python #artificialintelligence Running Jupyter Notebook on Visual Studio Code https://t.c…',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#   'created_at': 'Mon Apr 28 10:50:14 +0000 2014',
#   'default_profile': True,
#   'default_profile_image': False,
#   'description': 'Technophile | Pythonista |大好きなコンピュータプログラミング言語は#Pythonです｡ Sometimes a Bot➖Sometimes a Human➖Sometimes Both. Alumnusجامعة جوبا University of Juba. Runs @junub_bot',
#   'entities': {'description': {'urls': []},
#    'url': {'urls': [{'display_url': 'manzugerald.com',
#       'expanded_url': 'https://manzugerald.com',
#       'indices': [0, 23],
#       'url': 'https://t.co/H9hhWWGPL4'}]}},
#   'favourites_count': 198,
#   'follow_request_sent': False,
#   'followers_count': 3944,
#   'following': False,
#   'friends_count': 3884,
#   'geo_enabled': True,
#   'has_extended_profile': True,
#   'id': 2467565462,
#   'id_str': '2467565462',
#   'is_translation_enabled': False,
#   'is_translator': False,
#   'lang': None,
#   'listed_count': 10,
#   'location': '🇯🇵東京都調布市',
#   'name': 'Gerald Manzu',
#   'notifications': False,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2467565462/1626430499',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1428679422320599041/UJFSXs-K_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1428679422320599041/UJFSXs-K_normal.jpg',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'protected': False,
#   'screen_name': 'Mansuk_Lo_Rume',
#   'statuses_count': 28134,
#   'time_zone': None,
#   'translator_type': 'none',
#   'url': 'https://t.co/H9hhWWGPL4',
#   'utc_offset': None,
#   'verified': False,
#   'withheld_in_countries': []}}

# %% [markdown]
# Note that each tweet obtained from this API contains a `'user'` field -- this is a User Object for the user who created the tweet.

# %%
tweet['user']
# Out:
# {'contributors_enabled': False,
#  'created_at': 'Mon Apr 28 10:50:14 +0000 2014',
#  'default_profile': True,
#  'default_profile_image': False,
#  'description': 'Technophile | Pythonista |大好きなコンピュータプログラミング言語は#Pythonです｡ Sometimes a Bot➖Sometimes a Human➖Sometimes Both. Alumnusجامعة جوبا University of Juba. Runs @junub_bot',
#  'entities': {'description': {'urls': []},
#   'url': {'urls': [{'display_url': 'manzugerald.com',
#      'expanded_url': 'https://manzugerald.com',
#      'indices': [0, 23],
#      'url': 'https://t.co/H9hhWWGPL4'}]}},
#  'favourites_count': 198,
#  'follow_request_sent': False,
#  'followers_count': 3944,
#  'following': False,
#  'friends_count': 3884,
#  'geo_enabled': True,
#  'has_extended_profile': True,
#  'id': 2467565462,
#  'id_str': '2467565462',
#  'is_translation_enabled': False,
#  'is_translator': False,
#  'lang': None,
#  'listed_count': 10,
#  'location': '🇯🇵東京都調布市',
#  'name': 'Gerald Manzu',
#  'notifications': False,
#  'profile_background_color': 'C0DEED',
#  'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_tile': False,
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2467565462/1626430499',
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/1428679422320599041/UJFSXs-K_normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1428679422320599041/UJFSXs-K_normal.jpg',
#  'profile_link_color': '1DA1F2',
#  'profile_sidebar_border_color': 'C0DEED',
#  'profile_sidebar_fill_color': 'DDEEF6',
#  'profile_text_color': '333333',
#  'profile_use_background_image': True,
#  'protected': False,
#  'screen_name': 'Mansuk_Lo_Rume',
#  'statuses_count': 28134,
#  'time_zone': None,
#  'translator_type': 'none',
#  'url': 'https://t.co/H9hhWWGPL4',
#  'utc_offset': None,
#  'verified': False,
#  'withheld_in_countries': []}

# %% [markdown]
# ## 4.2 Using a cursor to get more than 100 tweets from a search
#
# We can only fetch up to 100 tweets at a time from a single search API call:

# %%
# even with count=1000, we still get at most 100 tweets
search_response = twitter.search(q='#datascience', count=1000)
len(search_response['statuses'])
# Out:
# 100

# %% [markdown]
# In order to get more tweets from a search, we can make use of a cursor:

# %%
import itertools

NUM_TWEETS_TO_FETCH = 1000

cursor = twitter.cursor(twitter.search, q='#datascience', count=100, result_type='mixed')
search_tweets = list(itertools.islice(cursor, NUM_TWEETS_TO_FETCH))
len(search_tweets)
# Out:
# 1000

# %%
import pandas as pd

# Search tweets
dict_ = {'user': [], 'date': [], 'text': [], 'favorite_count': []}
for tweet in search_tweets:
    dict_['user'].append(tweet['user']['screen_name'])
    dict_['date'].append(tweet['created_at'])
    dict_['text'].append(tweet['text'])
    dict_['favorite_count'].append(tweet['favorite_count'])
# Structure data in a pandas DataFrame for easier manipulation
df = pd.DataFrame(dict_)

# %%
df.head()
# Out:
#              user  ... favorite_count
# 0          mitsmr  ...             39
# 1      KirkDBorne  ...             63
# 2      KirkDBorne  ...             43
# 3  TheCuriousLuke  ...              0
# 4  cybersec_feeds  ...              0
#
# [5 rows x 4 columns]

# %%
df.shape
# Out:
# (1000, 4)

# %% [markdown]
# Note the following:
# * The cursor object is a
# [generator](https://docs.python.org/3/tutorial/classes.html#generators),
# a type of iterator that "lazily" generates items. We use Python's `itertools.islice` in order to get up to a set number of items from this generator. The second argument passed to `islice` is the max number of tweets we want to fetch from the user.
# * Even though we want to get more than 100 tweets here, we provide the `count=100` argument. This tells the cursor to fetch the maximum number of tweets with each API call.
# * As documented in [Twitter's Search API documentation](https://developer.twitter.com/en/docs/tweets/search/api-reference/get-search-tweets.html), specifying `result_type='mixed'` provides a mix of recent and popular tweets matching the query. If one desires a more "random" sample, you can specify `result_type='recent'`, but Twitter may provide fewer tweets than desired.

# %% [markdown]
# ## 4.3 API method rate limits
#
# Each API method has a *rate limit* imposed by Twitter, a limit on the number of function calls per 15-minute window. We can check on the rate limit status for this endpoint:

# %%
twitter.get_application_rate_limit_status()['resources']['search']
# Out:
# {'/search/tweets': {'limit': 180, 'remaining': 136, 'reset': 1631613874}}

# %% [markdown]
# These limits apply to the number of API *calls*, as opposed to the number of *items* fetched. This is why, when creating a cursor, we specify `count=` to fetch the maximum number of items per API call.

# %% [markdown]
# # 5.0 Creating social network graphs

# %% [markdown]
# In the remaining sections of this lesson, we're going to use NetworkX to create social networks from Twitter data. The examples are going to have users as nodes, so at a very basic level, we're going to do something like the following:

# %%
import networkx as nx

D = nx.DiGraph()

university = twitter.show_user(screen_name='ufrnbr')
author = twitter.show_user(screen_name='ivanovitchm')

D.add_edge(university['screen_name'], author['screen_name'], weight=1)

# %%
list(D.edges(data=True))
# Out:
# [('ufrnbr', 'ivanovitchm', {'weight': 1})]

# %% [markdown]
# Note that NetworkX will let us use the full user dictionaries as the node names, e.g. `D.add_edge(university, author)`. However, it is inconvenient to work with such a graph. More preferable is to use `screen_name` or `id` as the node names, and then use
# [node attributes](https://networkx.github.io/documentation/stable/tutorial.html#node-attributes)
# for the user profile data if desired.

# %% [markdown]
# # 6.0 Twitter retweet network

# %% [markdown]
# One fundamental interaction in the Twitter ecosystem is the "retweet" -- rebroadcasting another user's tweet to your followers. A tweet object returned by the API is a retweet if it includes a `'retweeted_status'`. We're going to fetch tweets matching a hashtag and create a retweet network of the conversation.

# %% [markdown]
# ## 6.1 Get some tweets

# %%
twitter.get_application_rate_limit_status()['resources']['search']
# Out:
# {'/search/tweets': {'limit': 180, 'remaining': 180, 'reset': 1631616213}}

# %%
#import itertools

#NUM_TWEETS_TO_FETCH = 17000

#cursor = twitter.cursor(twitter.search, q='datascience', count=100, result_type='mixed')
#search_tweets = list(itertools.islice(cursor, NUM_TWEETS_TO_FETCH))
#len(search_tweets)
# Out:
# 17000

# %%
#Using the sleep function to get more data
import itertools
import time

NUM_TWEETS_TO_FETCH = 17000

cursor = twitter.cursor(twitter.search, q='DataScience', count=100, result_type='mixed')
search_tweets = []

for i in range(3):
  search_tweets.extend(list(itertools.islice(cursor, NUM_TWEETS_TO_FETCH)))
  time.sleep(901) #15 minutos

len(search_tweets)
# Out:
# 51000

# %%
search_tweets[0]
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Tue Sep 14 04:02:01 +0000 2021',
#  'entities': {'hashtags': [{'indices': [0, 12], 'text': 'Datascience'}],
#   'symbols': [],
#   'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#     'expanded_url': 'https://twitter.com/i/web/status/1437627670708342790',
#     'indices': [117, 140],
#     'url': 'https://t.co/G4P6Vn8RJR'}],
#   'user_mentions': []},
#  'favorite_count': 39,
#  'favorited': False,
#  'geo': None,
#  'id': 1437627670708342790,
#  'id_str': '1437627670708342790',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'metadata': {'iso_language_code': 'en', 'result_type': 'popular'},
#  'place': None,
#  'possibly_sensitive': False,
#  'retweet_count': 21,
#  'retweeted': False,
#  'source': '<a href="https://sproutsocial.com" rel="nofollow">Sprout Social</a>',
#  'text': '#Datascience project management should be a continuous loop: The organization’s overall strategy feeds into directi… https://t.co/G4P6Vn8RJR',
#  'truncated': True,
#  'user': {'contributors_enabled': False,
#   'created_at': 'Fri Aug 01 17:55:38 +0000 2008',
#   'default_profile': False,
#   'default_profile_image': False,
#   'description': 'Transforming how people lead and innovate.',
#   'entities': {'description': {'urls': []},
#    'url': {'urls': [{'display_url': 'sloanreview.mit.edu',
#       'expanded_url': 'https://www.sloanreview.mit.edu',
#       'indices': [0, 23],
#       'url': 'https://t.co/ikTXUeirp1'}]}},
#   'favourites_count': 19209,
#   'follow_request_sent': False,
#   'followers_count': 151897,
#   'following': False,
#   'friends_count': 1696,
#   'geo_enabled': False,
#   'has_extended_profile': False,
#   'id': 15692087,
#   'id_str': '15692087',
#   'is_translation_enabled': False,
#   'is_translator': False,
#   'lang': None,
#   'listed_count': 4879,
#   'location': 'Cambridge, MA, USA',
#   'name': 'MIT Sloan Management Review',
#   'notifications': False,
#   'profile_background_color': '9E2020',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#   'profile_background_tile': True,
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/15692087/1631108709',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1378064551548178434/LYhePQxk_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1378064551548178434/LYhePQxk_normal.jpg',
#   'profile_link_color': '990000',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': 'EFEFEF',
#   'profile_text_color': '333333',
#   'profile_use_background_image': False,
#   'protected': False,
#   'screen_name': 'mitsmr',
#   'statuses_count': 68755,
#   'time_zone': None,
#   'translator_type': 'none',
#   'url': 'https://t.co/ikTXUeirp1',
#   'utc_offset': None,
#   'verified': True,
#   'withheld_in_countries': []}}

# %% [markdown]
# ## 6.2 Filter retweets

# %% [markdown]
# Of the tweets we fetched, a subset will be retweets. Let's create a new list of just the retweets:

# %%
retweets = []
for tweet in search_tweets:
    if 'retweeted_status' in tweet:
        retweets.append(tweet)
len(retweets)
# Out:
# 45490

# %%
# a retweet
retweets[0]
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Tue Sep 14 10:29:02 +0000 2021',
#  'entities': {'hashtags': [{'indices': [22, 36], 'text': '100DaysOfCode'},
#    {'indices': [56, 63], 'text': 'RStats'},
#    {'indices': [77, 84], 'text': 'Python'},
#    {'indices': [89, 101], 'text': 'DataScience'},
#    {'indices': [106, 130], 'text': 'ArtificiallIntelligence'}],
#   'symbols': [],
#   'urls': [],
#   'user_mentions': [{'id': 2477954400,
#     'id_str': '2477954400',
#     'indices': [3, 13],
#     'name': 'raja007',
#     'screen_name': 'raja00710'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 1437725069338423297,
#  'id_str': '1437725069338423297',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#  'place': None,
#  'retweet_count': 1,
#  'retweeted': False,
#  'retweeted_status': {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Sep 14 10:28:57 +0000 2021',
#   'entities': {'hashtags': [{'indices': [7, 21], 'text': '100DaysOfCode'},
#     {'indices': [41, 48], 'text': 'RStats'},
#     {'indices': [62, 69], 'text': 'Python'},
#     {'indices': [74, 86], 'text': 'DataScience'},
#     {'indices': [91, 115], 'text': 'ArtificiallIntelligence'}],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#      'expanded_url': 'https://twitter.com/i/web/status/1437725047544631296',
#      'indices': [117, 140],
#      'url': 'https://t.co/jlJLjRME9x'}],
#    'user_mentions': []},
#   'favorite_count': 1,
#   'favorited': False,
#   'geo': None,
#   'id': 1437725047544631296,
#   'id_str': '1437725047544631296',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 1,
#   'retweeted': False,
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'text': 'Day 45 #100DaysOfCode \nTime to begin \n1) #RStats  Basics. \n2) #Python for #DataScience And #ArtificiallIntelligence… https://t.co/jlJLjRME9x',
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon May 05 07:09:21 +0000 2014',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'entertainment.funloving braodminded guy very hot guy',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 3167,
#    'follow_request_sent': False,
#    'followers_count': 171,
#    'following': False,
#    'friends_count': 5004,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 2477954400,
#    'id_str': '2477954400',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': None,
#    'listed_count': 2,
#    'location': 'chennai',
#    'name': 'raja007',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1399001896405245956/DlLBAb8L_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1399001896405245956/DlLBAb8L_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'raja00710',
#    'statuses_count': 71397,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False,
#    'withheld_in_countries': []}},
#  'source': '<a href="https://dreamsofimran.in" rel="nofollow">TheDeveloperBot</a>',
#  'text': 'RT @raja00710: Day 45 #100DaysOfCode \nTime to begin \n1) #RStats  Basics. \n2) #Python for #DataScience And #ArtificiallIntelligence.\n3)  #Ma…',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#   'created_at': 'Tue Apr 14 20:51:03 +0000 2020',
#   'default_profile': True,
#   'default_profile_image': False,
#   'description': "I'm a bot created by @DreamsOfImran with a little bit of NodeJs and lots of ❤️\nI like and retweet posts related to #javascript, #vuejs, #reactjs, #Nodejs & etc",
#   'entities': {'description': {'urls': []}},
#   'favourites_count': 364161,
#   'follow_request_sent': False,
#   'followers_count': 4599,
#   'following': False,
#   'friends_count': 1,
#   'geo_enabled': False,
#   'has_extended_profile': False,
#   'id': 1250164632968298497,
#   'id_str': '1250164632968298497',
#   'is_translation_enabled': False,
#   'is_translator': False,
#   'lang': None,
#   'listed_count': 63,
#   'location': '',
#   'name': 'The Developer Bot',
#   'notifications': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1250164632968298497/1586966908',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1250454907871580162/Al-vkUN1_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1250454907871580162/Al-vkUN1_normal.jpg',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'protected': False,
#   'screen_name': 'TheDeveloperBot',
#   'statuses_count': 915008,
#   'time_zone': None,
#   'translator_type': 'none',
#   'url': None,
#   'utc_offset': None,
#   'verified': False,
#   'withheld_in_countries': []}}

# %% [markdown]
# ## 6.3 Create DiGraph

# %% [markdown]
# Each tweet in this list of retweets represents an edge in our network. <font color='red'>We're going to draw these edges in the direction of information flow</font>: from the retweeted user to the retweeter, the user doing the retweeting. Since a user can retweet another user more than once, we want this graph to be weighted, with the number of retweets as the weight.

# %%
import networkx as nx

D = nx.DiGraph()

for retweet in retweets:
    retweeted_status = retweet['retweeted_status']
    retweeted_sn = retweeted_status['user']['screen_name']
    retweeter_sn = retweet['user']['screen_name']
    
    # Edge direction: retweeted_sn -> retweeter_sn
    if D.has_edge(retweeted_sn, retweeter_sn):
        D.edges[retweeted_sn, retweeter_sn]['weight'] += 1
    else:
        D.add_edge(retweeted_sn, retweeter_sn, weight=1)

# %% [markdown]
# The edge addition logic here is to increase the edge weight by 1 if the edge exists, or else create the edge with weight 1 if it does not exist.
#
# When writing code such as this that refers multiple times to the same directed edge, make sure to be consistent with the edge direction.

# %% [markdown]
# ## 6.4 Analyze graph

# %% [markdown]
# Now that we have this graph, let's ask some questions about it.

# %% [markdown]
# ### 6.4.1 Most retweeted user

# %% [markdown]
# Since the edges are in the direction of information flow, out-degree gives us the number of other users retweeting a given user. We can get the user with highest out-degree using the built-in `max` function:

# %%
max(D.nodes, key=D.out_degree)
# Out:
# 'PrUkkera'

# %% [markdown]
# but we can get more context and information from the "top N" users:

# %%
from operator import itemgetter

sorted(D.out_degree(), key=itemgetter(1), reverse=True)[:20]
# Out:
# [('PrUkkera', 450),
#  ('Sheraj99', 251),
#  ('KirkDBorne', 223),
#  ('gp_pulipaka', 195),
#  ('Doxyaxone', 186),
#  ('ingliguori', 168),
#  ('sayalook', 162),
#  ('SourabhSKatoch', 157),
#  ('Khulood_Almani', 142),
#  ('mytrashcode', 141),
#  ('Paula_Piccard', 137),
#  ('icymi_py', 123),
#  ('chidambara09', 121),
#  ('programmerjoke9', 119),
#  ('marcusborba', 118),
#  ('IainLJBrown', 114),
#  ('kr_vaibhaw', 108),
#  ('PDH_SciTechNews', 106),
#  ('machinelearnflx', 106),
#  ('Eli_Krumova', 105)]

# %%
D.out_degree()
# Out:
# OutDegreeView({'raja00710': 27, 'TheDeveloperBot': 0, 'Khulood_Almani': 142, 'datasciencebot_': 0, 'wmktech': 90, 'andrewmorrisuk': 0, 'OlivyaEssays': 15, 'icymi_py': 123, 'pavellogacev': 0, 'sectest9': 0, 'ivybarley': 3, 'sc_agyapong': 0, 'KirkDBorne': 223, 'An_Indian_Otaku': 0, 'cybersec_feeds': 0, 'PDH_SciTechNews': 106, 'JavaGeekBot': 0, 'cryptomen20': 11, 'fluttbot': 0, 'opensource_orgs': 0, '_M_Dey': 75, 'SATYAJIT1910': 0, 'xaelbot': 0, 'hubofml': 0, 'py_data_sci': 0, 'SkaFolding_One': 0, 'Sheraj99': 251, 'botfordev': 0, 'MLOpsBot': 0, 'ServerlessFan': 0, 'LouiseNeuro': 1, 'liamebrowne': 0, 'E_ssayPro': 11, 'CodingPseudo': 61, '100DaysOf2020': 0, 'heshambindayel': 0, 'ingliguori': 168, 'arunkg99': 0, 'ume_kyd': 3, 'kofiklu__': 0, 'Uniplym_RnI': 1, 'ioannapapaniko6': 0, 'rweekly_live': 5, 'Pierre_Pgt': 0, 'CoderRetweet': 0, 'Grepnetics': 51, 'BotFemale': 0, 'WajdiAlkayal': 92, 'DjangoBot_': 0, '_ganeshp': 0, 'Oi_Penelope': 0, 'machinelearnflx': 106, 'sudiptamalakar4': 0, 'hailtothetsar': 0, 'PythonExpertBot': 0, 'TurboHire': 41, 'PythonRoboto': 0, 'KristiAlvarad0': 0, 'gilberto_sassi': 0, 'TechieTalkiez': 0, 'WalterAnalytics': 0, 'graders_a': 19, 'GridDBCommunity': 4, 'JannebyA': 0, 'ihuvila': 1, 'carwash': 0, 'automeme': 31, 'ingenium_rg': 1, 'Isaac_Segovia_': 0, '1Lpic': 1, 'SudheerPhDJNU': 100, 'AskamRobert': 0, 'TrendingNews_7': 36, 'bot_flutter': 0, 'Eli_Krumova': 105, 'rahul05ranjan': 0, 'BeatrixTait': 1, 'uCloudifyAI': 0, 'IainLJBrown': 114, 'iPythonistaBot': 0, 'FeatSystems': 0, 'Barackhalogen_': 22, 'Joffreybvn': 0, 'codedailybot': 0, 'NikseamC': 86, 'TeamPatriot007': 71, 'kr_vaibhaw': 108, 'Doxyaxone': 186, 'CazadorTrinos': 0, 'ind__ds': 0, 'cegama': 0, 'webwppro': 55, 'appthisway': 0, 'CyberSecurityN8': 0, 'TheSecretJunio1': 0, 'PrUkkera': 450, 'AzuerBot': 0, 'Harry_Robots': 1, 'New081082': 73, 'realrubberduck1': 0, 'DataScienceDojo': 33, 'blackpeopledata': 0, 'fullNam35087976': 0, 'Bills_Bot': 0, 'nilvana_ai': 1, 'wang_taka': 0, 'TBordikar': 1, 'AlkayalWajdi': 82, 'BonnieMaughan': 14, 'cont_learn': 0, 'dataworkout': 57, 'RobynPope83': 0, 'Fernandod': 0, 'machine_ml': 86, 'DeveloperBot_v1': 0, 'kosalanuwan': 0, 'rahulmeher': 0, 'BenjaminP3ters': 0, 'cesarpo_ghdz': 0, 'andi_staub': 73, 'Insurtrek': 0, 'ManofSamurai700': 0, 'sh_hameed': 55, 'NovaIntegra': 0, 'Paula_Piccard': 137, 'sayalook': 162, 'morolswediu': 0, 'team_backend': 0, 'AltaSoftRD': 0, 'ExperimentWorld': 0, 'alkayal_wajdi': 87, 'allenrevans': 0, 'geraldmuvengei2': 0, 'ValentineKalu01': 58, 'TheCuriousLuke': 0, 'SourabhSKatoch': 157, 'JereSantochi': 0, 'div_moh': 0, 'mytrashcode': 141, 'chidambara09': 121, 'hmCuesta': 10, 'sprint_code': 0, 'AndrewinContact': 62, 'Bridgin_D_Gaps': 0, 'stetfortis': 0, 'CodeWithTwitchi': 0, 'machinelearnTec': 39, 'wil_bielert': 78, 'ml_india_': 77, '_Simpson_Ke': 1, '_mwathi_MR': 0, 'lvaroInostroza': 1, 'neo4j': 11, 'GeoLogistico': 0, 'the404code': 0, 'MartinDP186': 0, 'DevHighlights': 0, 'arifth10': 0, 'kutieme888': 6, 'couponfree01': 24, 'fadhil_nimrod': 0, 'ike_b0': 0, 'JFSebastian146': 0, 'GentooBot': 0, 'berhanturk': 0, 'Calcaware': 0, 'VBurtila': 0, 'webcodebot': 0, '1235Googel': 1, 'configuroweb': 43, 'TheInfiltred': 0, 'Ronald_vanLoon': 86, 'migster_suave': 0, 'Momentum989': 0, '_Sivasai': 35, 'newbie_codes': 0, 'robertoromerog': 0, 'AnkitKa91977421': 0, 'jochenleidner': 0, 'MDSHISHIR360': 1, 'MdTushe78390833': 0, 'DataAISummit': 8, 'balram_prasad': 0, 'jamilahmed_16': 41, 'GamebotIndie': 0, 'denver_ltd': 15, 'sinhanavin1': 1, 'fabianorodrigo': 0, 'programmerjoke9': 119, '_INPST': 0, 'hfvidl122': 23, 'mrkuldeep8128': 1, 'HeptagonTech': 21, 'Prometheus_Bot': 0, 'PenaRodery': 0, 'rasangarocks': 99, 'XeronBot': 0, 'Udemy_Coupons1': 97, 'jackiemorelli': 33, 'Academics_team': 28, 'codebot12': 0, '2Bftawfik': 0, 'Hackingdom_io': 0, 'dilan_jayy': 11, 'powerplatfrmbot': 0, 'supremehub_': 6, 'topclassguide': 4, 'TheInsaneApp': 32, 'Allanmutisya4': 23, 'yoselino': 0, 'LincolnMunene9': 0, 'DevelopOneill': 0, 'cuongcz': 14, ...

# %% [markdown]
# In this piece of code, we take advantage of the fact that `D.out_degree()` returns a sequence of `(name, degree)` 2-tuples; specifying `key=itemgetter(1)` tells the `sorted` function to sort these 2-tuples by their value at index 1. Giving `reverse=True` tells the `sorted` function that we want this in descending order, and the `[:5]` at the end slices the first 5 items from the resulting list.
#
# However, this is a weighted graph! By default, `out_degree()` ignores the edge weights. We can get out-strength by telling the `out_degree()` function to take into account the edge weight:

# %%
sorted(D.out_degree(weight='weight'), key=itemgetter(1), reverse=True)[:20]
# Out:
# [('Doxyaxone', 1563),
#  ('PrUkkera', 1518),
#  ('Sheraj99', 1437),
#  ('sayalook', 1335),
#  ('IainLJBrown', 1129),
#  ('chidambara09', 1056),
#  ('gp_pulipaka', 937),
#  ('rasangarocks', 816),
#  ('Khulood_Almani', 771),
#  ('akbarth3great', 769),
#  ('Udemy_Coupons1', 712),
#  ('Paula_Piccard', 670),
#  ('PDH_SciTechNews', 652),
#  ('NikseamC', 652),
#  ('JobPreference', 652),
#  ('KirkDBorne', 606),
#  ('programmerjoke9', 592),
#  ('bluejak3', 579),
#  ('marcusborba', 572),
#  ('TeamPatriot007', 549)]

# %% [markdown]
# In some cases these two results will be the same, namely if none of these users has been retweeted multiple times by the same user. Depending on your use case, you may or may not wish to take the weights into account.

# %% [markdown]
# ### 6.4.2 Anomaly detection

# %% [markdown]
# One type of social media manipulation involves accounts that create very little original content, instead "spamming" retweets of any and all content in a particular conversation. Can we detect any users doing significantly more retweeting than others? Let's look at the top N retweeters:

# %%
sorted(D.in_degree(weight='weight'), key=itemgetter(1), reverse=True)[:20]
# Out:
# [('iPythonistaBot', 1785),
#  ('team_backend', 1529),
#  ('DeveloperBot_v1', 1522),
#  ('100DaysOf2020', 1373),
#  ('AzuerBot', 1346),
#  ('CodeWithTwitchi', 1277),
#  ('Bills_Bot', 1210),
#  ('xaelbot', 1185),
#  ('CoderRetweet', 1184),
#  ('godfrey_G_', 1172),
#  ('DjangoBot_', 1164),
#  ('hubofml', 1129),
#  ('morolswediu', 1104),
#  ('XeronBot', 1084),
#  ('rahul05ranjan', 1073),
#  ('codedailybot', 997),
#  ('botfordev', 701),
#  ('Fabriciosx', 694),
#  ('datasciencebot_', 678),
#  ('cybersec_feeds', 654)]

# %% [markdown]
# ### 6.4.3 Connectivity

# %% [markdown]
# We can ask if the tweets obtained by the search represent one large conversation or many small conversations; broadly speaking, each weakly-connected component represents a conversation.

# %%
nx.is_weakly_connected(D)
# Out:
# False

# %%
nx.number_weakly_connected_components(D)
# Out:
# 186

# %% [markdown]
# ### 6.4.4 Drawing

# %% [markdown]
# We can try to draw this graph with the nodes sized by their out-strength:

# %%
node_sizes = [D.out_degree(n, weight='weight') * 50 for n in D.nodes]

# %matplotlib inline
nx.draw(D, node_size=node_sizes)

# %%
# filter nodes with degree greater than or equal to 1
core = [node for node, deg in dict(D.degree()).items() if deg >= 1]

# select a subgraph with 'core' nodes
gsub = nx.subgraph(D, core)

print("{} nodes, {} edges".format(len(gsub), nx.number_of_edges(gsub)))

nx.write_graphml(gsub, "ds12.graphml")
# Out:
# 4471 nodes, 16002 edges

# %% [markdown]
# Note that in this simplistic drawing, nodes with zero out-strength are not drawn on the diagram because their size is 0. This suits us fine; only the users who have been retweeted are drawn here.

# %%
import pandas as pd

# Search retweets
dictt_ = {'user': [], 'date': [], 'text': [], 'retweet_count': [], 'location': []}
for retweets in search_tweets:
    dictt_['user'].append(retweets['user']['screen_name'])
    dictt_['date'].append(retweets['created_at'])
    dictt_['text'].append(retweets['text'])
    dictt_['retweet_count'].append(retweets['retweet_count'])
    dictt_['location'].append(retweets['user']['location'])

# Structure data in a pandas DataFrame for easier manipulation
dff = pd.DataFrame(dictt_)
dff.head()
# Out:
#               user  ...            location
# 0           mitsmr  ...  Cambridge, MA, USA
# 1       KirkDBorne  ...       Maryland, USA
# 2       KirkDBorne  ...       Maryland, USA
# 3  TheDeveloperBot  ...
# 4          adolfCP  ...
#
# [5 rows x 5 columns]

# %%
dff.shape
# Out:
# (51000, 5)

# %%
# save to a csv file
dff.to_csv("datascience.csv")

# %% [markdown]
# #**7.0 EDA**

# %% [markdown]
# ##**Banco de dados**

# %%
ds = dff
ds.head()
# Out:
#               user  ...            location
# 0           mitsmr  ...  Cambridge, MA, USA
# 1       KirkDBorne  ...       Maryland, USA
# 2       KirkDBorne  ...       Maryland, USA
# 3  TheDeveloperBot  ...
# 4          adolfCP  ...
#
# [5 rows x 5 columns]

# %%
ds.shape
# Out:
# (51000, 5)

# %%
ds.describe()
# Out:
#        retweet_count
# count   51000.000000
# mean       57.786294
# std       149.752497
# min         0.000000
# 25%        12.000000
# 50%        32.000000
# 75%        63.000000
# max      6802.000000

# %%
ds.dtypes
# Out:
# user             object
# date             object
# text             object
# retweet_count     int64
# location         object
# dtype: object

# %%
print(ds.isna().sum())
# Out:
# user             0
# date             0
# text             0
# retweet_count    0
# location         0
# dtype: int64

# %% [markdown]
# ##**Usuário mais retweetado**

# %% [markdown]
# ###**Sem peso**

# %%
userplus = ds[ds['user']=='PrUkkera']
userplus.shape
# Out:
# (9, 5)

# %%
userplus
# Out:
#            user                            date  ... retweet_count  location
# 4007   PrUkkera  Mon Sep 13 00:00:01 +0000 2021  ...           278     Egypt
# 10705  PrUkkera  Sun Sep 12 19:00:00 +0000 2021  ...           122     Egypt
# 18879  PrUkkera  Sun Sep 12 14:00:00 +0000 2021  ...           140     Egypt
# 25294  PrUkkera  Sun Sep 12 10:00:00 +0000 2021  ...           157     Egypt
# 32013  PrUkkera  Sun Sep 12 06:00:00 +0000 2021  ...           118     Egypt
# 36559  PrUkkera  Sun Sep 12 02:00:01 +0000 2021  ...           177     Egypt
# 39691  PrUkkera  Sat Sep 11 23:00:00 +0000 2021  ...            74     Egypt
# 45045  PrUkkera  Sat Sep 11 19:00:00 +0000 2021  ...           159     Egypt
# 50917  PrUkkera  Sat Sep 11 15:00:02 +0000 2021  ...           185     Egypt
#
# [9 rows x 5 columns]

# %%
userplus['retweet_count'].sum()
# Out:
# 1410

# %% [markdown]
# ###**Com peso**

# %%
doxy = ds[ds['user']=='Doxyaxone']
doxy
# Out:
#             user                            date  ... retweet_count  location
# 15714  Doxyaxone  Sun Sep 12 15:52:27 +0000 2021  ...            57
# 15720  Doxyaxone  Sun Sep 12 15:52:23 +0000 2021  ...             3
# 29125  Doxyaxone  Sun Sep 12 07:37:13 +0000 2021  ...            61
# 29133  Doxyaxone  Sun Sep 12 07:36:51 +0000 2021  ...            15
# 29204  Doxyaxone  Sun Sep 12 07:34:12 +0000 2021  ...            30
# 29948  Doxyaxone  Sun Sep 12 07:11:46 +0000 2021  ...            32
# 29974  Doxyaxone  Sun Sep 12 07:10:48 +0000 2021  ...            19
# 30020  Doxyaxone  Sun Sep 12 07:08:56 +0000 2021  ...            36
# 30166  Doxyaxone  Sun Sep 12 07:05:23 +0000 2021  ...            24
# 30219  Doxyaxone  Sun Sep 12 07:03:34 +0000 2021  ...            29
# 30433  Doxyaxone  Sun Sep 12 06:56:10 +0000 2021  ...            11
# 30456  Doxyaxone  Sun Sep 12 06:55:15 +0000 2021  ...            35
# 30523  Doxyaxone  Sun Sep 12 06:53:02 +0000 2021  ...            47
# 30555  Doxyaxone  Sun Sep 12 06:52:19 +0000 2021  ...            21
# 30604  Doxyaxone  Sun Sep 12 06:51:08 +0000 2021  ...            25
# 30633  Doxyaxone  Sun Sep 12 06:50:19 +0000 2021  ...            28
# 30680  Doxyaxone  Sun Sep 12 06:49:15 +0000 2021  ...            31
# 30731  Doxyaxone  Sun Sep 12 06:48:17 +0000 2021  ...            22
# 30764  Doxyaxone  Sun Sep 12 06:46:57 +0000 2021  ...            48
# 30789  Doxyaxone  Sun Sep 12 06:46:15 +0000 2021  ...            73
# 30835  Doxyaxone  Sun Sep 12 06:45:17 +0000 2021  ...            86
# 30861  Doxyaxone  Sun Sep 12 06:44:25 +0000 2021  ...            28
# 30952  Doxyaxone  Sun Sep 12 06:41:30 +0000 2021  ...            51
# 30985  Doxyaxone  Sun Sep 12 06:40:25 +0000 2021  ...            21
# 31067  Doxyaxone  Sun Sep 12 06:37:09 +0000 2021  ...            29
# 31199  Doxyaxone  Sun Sep 12 06:32:55 +0000 2021  ...            20
# 31230  Doxyaxone  Sun Sep 12 06:31:11 +0000 2021  ...            41
# 31299  Doxyaxone  Sun Sep 12 06:28:03 +0000 2021  ...            19
# 31346  Doxyaxone  Sun Sep 12 06:25:45 +0000 2021  ...            22
# 31419  Doxyaxone  Sun Sep 12 06:23:02 +0000 2021  ...            21
# 31477  Doxyaxone  Sun Sep 12 06:21:10 +0000 2021  ...            21
# 31539  Doxyaxone  Sun Sep 12 06:18:51 +0000 2021  ...            22
# 31583  Doxyaxone  Sun Sep 12 06:17:15 +0000 2021  ...            27
# 31634  Doxyaxone  Sun Sep 12 06:15:19 +0000 2021  ...            32
# 31673  Doxyaxone  Sun Sep 12 06:13:50 +0000 2021  ...            55
# 31745  Doxyaxone  Sun Sep 12 06:11:56 +0000 2021  ...            42
# 31784  Doxyaxone  Sun Sep 12 06:10:46 +0000 2021  ...            42
# 31820  Doxyaxone  Sun Sep 12 06:09:20 +0000 2021  ...            33
# 31873  Doxyaxone  Sun Sep 12 06:07:15 +0000 2021  ...            29
# 31911  Doxyaxone  Sun Sep 12 06:05:22 +0000 2021  ...            24
# 31937  Doxyaxone  Sun Sep 12 06:03:27 +0000 2021  ...             2
# 31957  Doxyaxone  Sun Sep 12 06:02:46 +0000 2021  ...            16
# 31971  Doxyaxone  Sun Sep 12 06:02:08 +0000 2021  ...            60
# 50003  Doxyaxone  Sat Sep 11 15:50:04 +0000 2021  ...            26
# 50005  Doxyaxone  Sat Sep 11 15:49:57 +0000 2021  ...            23
# 50026  Doxyaxone  Sat Sep 11 15:48:40 +0000 2021  ...            18
#
# [46 rows x 5 columns]

# %%
doxy['retweet_count'].sum()
# Out:
# 1457

# %% [markdown]
# ##**Retweet count**

# %%
sort_val = ds.sort_values('retweet_count', ascending=False)
sort_val.head(30)
# Out:
#                   user  ...                    location
# 37530  Uqtw0zc7rhCjCEu  ...
# 4032         PovHonest  ...
# 24216    yomoyama_hana  ...
# 29257     Conodont1014  ...
# 28029   umenosuke_tani  ...                          東京
# 5958       bealive2020  ...                         東京
# 28406          ano_sci  ...
# 28989      kobaryu5000  ...
# 31955       teruichi81  ...
# 5925             ExG40  ...
# 30338  orthope_surgeon  ...                          関西
# 5891      lonepair1106  ...
# 27772      ayo_ayo_ebi  ...
# 6421        nomber8948  ...                愛のあるところ、居場所。
# 28595     african_beat  ...
# 13764       ensembrale  ...             エイジ・オブ・マッポーカリプス
# 50888  realrubberduck1  ...
# 50941       Fabriciosx  ...              Rio de janeiro
# 14572       godfrey_G_  ...  Johannesburg, South Africa
# 15842      morolswediu  ...           Dhaka, Bangladesh
# 15867   news__umbrella  ...
# 41990       godfrey_G_  ...  Johannesburg, South Africa
# 1546   PennilessScribe  ...           Vancouver, Canada
# 11010     CoderRetweet  ...                      Europe
# 13237        dfpwriter  ...                     Hamburg
# 44878         fluttbot  ...
# 11008          xaelbot  ...                       Earth
# 16066     team_backend  ...                         USA
# 44885  73A5u9tfmfU8O78  ...                      日本　栃木県
# 14968         Lizones1  ...            Willoughby, Ohio
#
# [30 rows x 5 columns]

# %%
sort_val['location'].groupby()

# %%
most_local = sort_val['location'].value_counts()

# %%
most_local[most_local> 600]
# Out:
#                               20073
# Earth                          2186
# USA                            1584
# Earth                          1373
# Jammu And Kashmir              1210
# Europe                         1186
# Johannesburg, South Africa     1179
# Germany                        1129
# Dhaka, Bangladesh              1113
# Internet                       1087
# Crawling Twitter               1084
# Chandigarh, India              1074
# #codedaily                      997
# Rio de janeiro                  694
# 127.0.0.1                       650
# Kyiv, Ukraine                   637
# Name: location, dtype: int64
